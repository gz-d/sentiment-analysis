# %%
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import re
import nltk
from nltk.corpus import stopwords
# nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Perceptron
from sklearn.metrics import precision_recall_fscore_support
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## 1. Dataset Preparation

# %%
# Read data
#df = pd.read_csv('C:/Users/guanz/OneDrive/Desktop/CSCI544/homework/HW1/data/amazon_reviews_us_Kitchen_v1_00.tsv', sep='\t', on_bad_lines='skip')
df = pd.read_csv('https://s3.amazonaws.com/amazon-reviews-pds/tsv/amazon_reviews_us_Kitchen_v1_00.tsv.gz', sep='\t', on_bad_lines='skip')

# %%
df = df[['star_rating', 'review_body']].rename(columns={'star_rating':'ratings', 'review_body':'reviews'})
df.head()
# Out:
#    ratings                                            reviews
# 0      5.0                Beautiful.  Looks great on counter.
# 1      5.0  I personally have 5 days sets and have also bo...
# 2      5.0  Fabulous and worth every penny. Used for clean...
# 3      5.0  A must if you love garlic on tomato marinara s...
# 4      5.0  Worth every penny! Buy one now and be a pizza ...

# %%
df.groupby('ratings').describe()
# Out:
#          reviews
#            count   unique        top  freq
# ratings
# 1.0       426870   419692  Too small   110
# 2.0       241939   239368  Too small   105
# 3.0       349539   342257         ok   550
# 4.0       731701   703142       good  1163
# 5.0      3124595  2876141      Great  5604

# %% [markdown]
# ## 2. Word Embedding

# %% [markdown]
# ### Load the pretrained Word2Vec model

# %%
# load the pretrained model as model1
pretrained = 'GoogleNews-vectors-negative300.bin.gz'
model1 = KeyedVectors.load_word2vec_format(pretrained, binary=True)

# %%
# check the similarity between two similar words
print(model1.similarity('excellent', 'outstanding'))

# find out the corresponding word given that A - B = C - D (King - Man = Queen - Woman)
print(model1.most_similar(positive=['king', 'woman'], negative=['man'], topn=1))
# Out:
# 0.5567486
# [('queen', 0.7118193507194519)]

# %% [markdown]
# ### Train a Word2Vec model using my own dataset

# %%
# X = df['reviews'].fillna('').tolist()

# %%
# convert reviews to lower case
# X = [str(x).lower() for x in X]
# remove HTML and URLs from reviews
# X = [re.sub('<.*>', '', x) for x in X]
# X = [re.sub(r'https?://\S+', '', x) for x in X]
# remove non-alphabetical characters
# X = [re.sub('[^a-z ]', '', x) for x in X]
# remove extra spaces
# X = [re.sub(' +', ' ', x) for x in X]

# %%
# expand contractions
'''contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}
def decontraction(s):
    for word in s.split(' '):
        if word in contractions.keys():
            s = re.sub(word, contractions[word], s)
    return s
X = [decontraction(x) for x in X]'''
# Out:
# 'contractions = { \n"ain\'t": "am not",\n"aren\'t": "are not",\n"can\'t": "cannot",\n"can\'t\'ve": "cannot have",\n"\'cause": "because",\n"could\'ve": "could have",\n"couldn\'t": "could not",\n"couldn\'t\'ve": "could not have",\n"didn\'t": "did not",\n"doesn\'t": "does not",\n"don\'t": "do not",\n"hadn\'t": "had not",\n"hadn\'t\'ve": "had not have",\n"hasn\'t": "has not",\n"haven\'t": "have not",\n"he\'d": "he would",\n"he\'d\'ve": "he would have",\n"he\'ll": "he will",\n"he\'ll\'ve": "he will have",\n"he\'s": "he is",\n"how\'d": "how did",\n"how\'d\'y": "how do you",\n"how\'ll": "how will",\n"how\'s": "how is",\n"I\'d": "I would",\n"I\'d\'ve": "I would have",\n"I\'ll": "I will",\n"I\'ll\'ve": "I will have",\n"I\'m": "I am",\n"I\'ve": "I have",\n"isn\'t": "is not",\n"it\'d": "it would",\n"it\'d\'ve": "it would have",\n"it\'ll": "it will",\n"it\'ll\'ve": "it will have",\n"it\'s": "it is",\n"let\'s": "let us",\n"ma\'am": "madam",\n"mayn\'t": "may not",\n"might\'ve": "might have",\n"mightn\'t": "might not",\n"mightn\'t\'ve": "might not have",\n"must\'ve": "must have",\n"mustn\'t": "must not",\n"mustn\'t\'ve": "must not have",\n"needn\'t": "need not",\n"needn\'t\'ve": "need not have",\n"o\'clock": "of the clock",\n"oughtn\'t": "ought not",\n"oughtn\'t\'ve": "ought not have",\n"shan\'t": "shall not",\n"sha\'n\'t": "shall not",\n"shan\'t\'ve": "shall not have",\n"she\'d": "she would",\n"she\'d\'ve": "she would have",\n"she\'ll": "she will",\n"she\'ll\'ve": "she will have",\n"she\'s": "she is",\n"should\'ve": "should have",\n"shouldn\'t": "should not",\n"shouldn\'t\'ve": "should not have",\n"so\'ve": "so have",\n"so\'s": "so is",\n"that\'d": "that would",\n"that\'d\'ve": "that would have",\n"that\'s": "that is",\n"there\'d": "there would",\n"there\'d\'ve": "there would have",\n"there\'s": "there is",\n"they\'d": "they would",\n"they\'d\'ve": "they would have",\n"they\'ll": "they will",\n"they\'ll\'ve": "they will have",\n"they\'re": "they are",\n"they\'ve": "they have",\n"to\'ve": "to have",\n"wasn\'t": "was not",\n"we\'d": "we would",\n"we\'d\'ve": "we would have",\n"we\'ll": "we will",\n"we\'ll\'ve": "we will have",\n"we\'re": "we are",\n"we\'ve": "we have",\n"weren\'t": "were not",\n"what\'ll": "what will",\n"what\'ll\'ve": "what will have",\n"what\'re": "what are",\n"what\'s": "what is",\n"what\'ve": "what have",\n"when\'s": "when is",\n"when\'ve": "when have",\n"where\'d": "where did",\n"where\'s": "where is",\n"where\'ve": "where have",\n"who\'ll": "who will",\n"who\'ll\'ve": "who will have",\n"who\'s": "who is",\n"who\'ve": "who have",\n"why\'s": "why is",\n"why\'ve": "why have",\n"will\'ve": "will have",\n"won\'t": "will not",\n"won\'t\'ve": "will not have",\n"would\'ve": "would have",\n"wouldn\'t": "would not",\n"wouldn\'t\'ve": "would not have",\n"y\'all": "you all",\n"y\'all\'d": "you all would",\n"y\'all\'d\'ve": "you all would have",\n"y\'all\'re": "you all are",\n"y\'all\'ve": "you all have",\n"you\'d": "you would",\n"you\'d\'ve": "you would have",\n"you\'ll": "you will",\n"you\'ll\'ve": "you will have",\n"you\'re": "you are",\n"you\'ve": "you have"\n}\ndef decontraction(s):\n    for word in s.split(\' \'):\n        if word in contractions.keys():\n            s = re.sub(word, contractions[word], s)\n    return s\nX = [decontraction(x) for x in X]'

# %%
# perform lemmatization
# wnl = WordNetLemmatizer()
# X = [' '.join([wnl.lemmatize(word) for word in x.split(' ')]) for x in X]

# %% [markdown]
# ### Here we didn't remove stop words from the dataset and this is because we are modeling the similarity between context and center words during modeling. If we removed stop words, we would not be able to model the true context.

# %%
# train a word2vec model using my own dataset
# convert X_train to a list of lists of words
# sentences = [x.split(' ') for x in X]

# use X_train to train a word2vec model2
# model2 = Word2Vec(vector_size=300, window=11, min_count=10)
# model2.build_vocab(sentences)
# model2.train(sentences, total_examples=model2.corpus_count, epochs=model2.epochs)

# %%
# save the trained model
# model2.save('my-own-word2vec.model')
# store just the words + their trained embeddings
# word_vectors = model2.wv
# word_vectors.save('my-own-word2vec.wordvectors')

# %%
model2 = KeyedVectors.load('my-own-word2vec.wordvectors', mmap='r')

# %%
# check the similarity between two similar words using model 2
print(model2.similarity('excellent', 'outstanding'))

# find out the corresponding word given that A - B = C - D (King - Man = Queen - Woman) using model 2
print(model2.most_similar(positive=['king', 'woman'], negative=['man'], topn=1))
# Out:
# 0.8761742
# [('queen', 0.5082318186759949)]

# %% [markdown]
# ## 3. Build training and testing datasets

# %%
# Build a balanced dataset of 250,000 reviews (50K instances per each rating score).
df_1 = df[df['ratings']==1].sample(n=50000, random_state=1)
df_2 = df[df['ratings']==2].sample(n=50000, random_state=1)
df_3 = df[df['ratings']==3].sample(n=50000, random_state=1)
df_4 = df[df['ratings']==4].sample(n=50000, random_state=1)
df_5 = df[df['ratings']==5].sample(n=50000, random_state=1)
df = pd.concat([df_1, df_2, df_3, df_4, df_5]).sample(frac=1).reset_index(drop=True)

# Create ternary labels: ratings > 3 --> 1, ratings < 3 --> 2, ratings = 3 --> 3
# Map ratings > 3 to 1, ratings < 3 to 2, and ratings = 3 to 3.
df['label'] = df['ratings'].map(lambda x: 1 if x > 3 else (2 if x < 3 else 3))
df.drop('ratings', axis=1, inplace=True)

df.groupby('label').describe()
# Out:
#       reviews
#         count unique        top freq
# label
# 1       99995  96477       good  149
# 2       99995  99276  too small   28
# 3       49997  49404         ok   74

# %%
X, y = df['reviews'].fillna('').tolist(), df['label'].tolist()

# %%
# convert reviews to lower case
X = [str(x).lower() for x in X]
# remove HTML and URLs from reviews
X = [re.sub('<.*>', '', x) for x in X]
X = [re.sub(r'https?://\S+', '', x) for x in X]
# remove non-alphabetical characters
X = [re.sub('[^a-z ]', '', x) for x in X]
# remove extra spaces
X = [re.sub(' +', ' ', x) for x in X]

# %%
# expand contractions
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}
def decontraction(s):
    for word in s.split(' '):
        if word in contractions.keys():
            s = re.sub(word, contractions[word], s)
    return s
X = [decontraction(x) for x in X]

# %%
# perform lemmatization
wnl = WordNetLemmatizer()
X = [' '.join([wnl.lemmatize(word) for word in x.split(' ')]) for x in X]

# %%
# remove stop words

stopWords =set(stopwords.words('english'))
def rmstopWords(s):
    wordlist = s.split(' ')
    newlist = []
    for word in wordlist:
        if word not in stopWords:
            newlist.append(word)
    s = ' '.join(newlist)
    return s

X = [rmstopWords(x) for x in X]

# %%
# Split the downsized dataset into 80% training dataset and 20% testing dataset.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# turn the original ternary training and testing datasets to binary
# return a list of indices of y = 1 or y =2
y_train_bi = []
idx_train = []
for i, y in enumerate(y_train):
    if y == 1 or y == 2:
        y_train_bi.append(y)
        idx_train.append(i)
        
y_test_bi = []
idx_test = []
for i, y in enumerate(y_test):
    if y == 1 or y == 2:
        y_test_bi.append(y)
        idx_test.append(i)
# use the list of indices to select a sub-list of X_train
X_train_bi = [X_train[i] for i in idx_train]
X_test_bi = [X_test[i] for i in idx_test]

# %%
len(X_train)
# Out:
# 200000

# %% [markdown]
# ## 4. Simple Models

# %% [markdown]
# ### Use the pretrained word2vec model to train models (perceptron and SVM)

# %%
# take the average word vectors of important words (i.e. non-stop words) in
# a review as the feature of a training sample
X_train_bi1 = []
for x in X_train_bi:
    wordveclist = []
    for word in x.split(' '):
        try:
            wordvec = model1[word]
            wordveclist.append(wordvec)
        except:
            pass
    X_train_bi1.append(np.mean(wordveclist, axis=0))
# Out:
# C:\Users\guanz\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\guanz\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
X_test_bi1 = []
for x in X_test_bi:
    wordveclist = []
    for word in x.split(' '):
        try:
            wordvec = model1[word]
            wordveclist.append(wordvec)
        except:
            pass
    X_test_bi1.append(np.mean(wordveclist, axis=0))

# %%
# handle non-word-vector values in the dataset
# return the indices of word-vector values
wv_train = []
for i, x in enumerate(X_train_bi1):
    try:
        len(x)
        wv_train.append(i)
    except:
        print(x)
        

wv_test = []
for i, x in enumerate(X_test_bi1):
    try:
        len(x)
        wv_test.append(i)
    except:
        print(x)
        
# remove the non-word-vector values from the dataset
X_train_bi1 = [X_train_bi1[i] for i in wv_train]
X_test_bi1 = [X_test_bi1[i] for i in wv_test]
y_train_bi1 = [y_train_bi[i] for i in wv_train]
y_test_bi1 = [y_test_bi[i] for i in wv_test]
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
# use pretrained word2vec features to train a perceptron
perceptron = Perceptron(random_state=1)
perceptron.fit(X_train_bi1, y_train_bi1)
y_train_predict1, y_test_predict1 = perceptron.predict(X_train_bi1), perceptron.predict(X_test_bi1)

# report accuracy, precision, recall, and f1-score on both the training and testing split
train_stats = precision_recall_fscore_support(y_train_bi1, y_train_predict1, average='binary')
precision_train, recall_train, fscore_train = train_stats[0], train_stats[1], train_stats[2]

test_stats = precision_recall_fscore_support(y_test_bi1, y_test_predict1, average='binary')
precision_test, recall_test, fscore_test = test_stats[0], test_stats[1], test_stats[2]

print('The accuracy of training dataset: {:2.1%}'.format(perceptron.score(X_train_bi1, y_train_bi1)))
print('The precision of training dataset: {:2.1%}'.format(precision_train))
print('The recall of training dataset: {:2.1%}'.format(recall_train))
print('The fscore of training dataset: {:2.1%}\n'.format(fscore_train))

print('The accuracy of testing dataset: {:2.1%}'.format(perceptron.score(X_test_bi1, y_test_bi1)))
print('The precision of testing dataset: {:2.1%}'.format(precision_test))
print('The recall of testing dataset: {:2.1%}'.format(recall_test))
print('The fscore of testing dataset: {:2.1%}'.format(fscore_test))
# Out:
# The accuracy of training dataset: 77.7%
# The precision of training dataset: 85.0%
# The recall of training dataset: 67.3%
# The fscore of training dataset: 75.1%
#
# The accuracy of testing dataset: 77.4%
# The precision of testing dataset: 84.6%
# The recall of testing dataset: 66.7%
# The fscore of testing dataset: 74.6%

# %%
# use pretrained word2vec features to train a SVM
# refer to https://stackoverflow.com/questions/52008548/python-running-into-x-test-y-test-fit-errors
# for why with_mean should be set to False
svm = LinearSVC(random_state=1)
svm.fit(X_train_bi1, y_train_bi1)

y_train_predict1, y_test_predict1 = svm.predict(X_train_bi1), svm.predict(X_test_bi1)

# report accuracy, precision, recall, and f1-score on both the training and testing split
train_stats = precision_recall_fscore_support(y_train_bi1, y_train_predict1, average='binary')
precision_train, recall_train, fscore_train = train_stats[0], train_stats[1], train_stats[2]

test_stats = precision_recall_fscore_support(y_test_bi1, y_test_predict1, average='binary')
precision_test, recall_test, fscore_test = test_stats[0], test_stats[1], test_stats[2]

print('The accuracy of training dataset: {:2.1%}'.format(svm.score(X_train_bi1, y_train_bi1)))
print('The precision of training dataset: {:2.1%}'.format(precision_train))
print('The recall of training dataset: {:2.1%}'.format(recall_train))
print('The fscore of training dataset: {:2.1%}\n'.format(fscore_train))

print('The accuracy of testing dataset: {:2.1%}'.format(svm.score(X_test_bi1, y_test_bi1)))
print('The precision of testing dataset: {:2.1%}'.format(precision_test))
print('The recall of testing dataset: {:2.1%}'.format(recall_test))
print('The fscore of testing dataset: {:2.1%}'.format(fscore_test))
# Out:
# The accuracy of training dataset: 81.9%
# The precision of training dataset: 83.3%
# The recall of training dataset: 79.7%
# The fscore of training dataset: 81.5%
#
# The accuracy of testing dataset: 81.5%
# The precision of testing dataset: 82.8%
# The recall of testing dataset: 79.4%
# The fscore of testing dataset: 81.1%

# %% [markdown]
# ### Use my own word2vec model to train models (perceptron and SVM)

# %%
# take the average word vectors of important words (i.e. non-stop words) in
# a review as the feature of a training sample
X_train_bi2 = []
for x in X_train_bi:
    wordveclist = []
    for word in x.split(' '):
        try:
            wordvec = model2[word]
            wordveclist.append(wordvec)
        except:
            pass
    X_train_bi2.append(np.mean(wordveclist, axis=0))

# do the same to the testing dataset
X_test_bi2 = []
for x in X_test_bi:
    wordveclist = []
    for word in x.split(' '):
        try:
            wordvec = model2[word]
            wordveclist.append(wordvec)
        except:
            pass
    X_test_bi2.append(np.mean(wordveclist, axis=0))
# Out:
# C:\Users\guanz\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\guanz\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# handle non-word-vector values in the dataset
# return the indices of word-vector values
wv_train = []
for i, x in enumerate(X_train_bi2):
    try:
        len(x)
        wv_train.append(i)
    except:
        print(x)
        

wv_test = []
for i, x in enumerate(X_test_bi2):
    try:
        len(x)
        wv_test.append(i)
    except:
        print(x)
        
# remove the non-word-vector values from the dataset
X_train_bi2 = [X_train_bi2[i] for i in wv_train]
X_test_bi2 = [X_test_bi2[i] for i in wv_test]
y_train_bi2 = [y_train_bi[i] for i in wv_train]
y_test_bi2 = [y_test_bi[i] for i in wv_test]
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
# use my own word2vec features to train a perceptron
perceptron = Perceptron(random_state=1)
perceptron.fit(X_train_bi2, y_train_bi2)
y_train_predict2, y_test_predict2 = perceptron.predict(X_train_bi2), perceptron.predict(X_test_bi2)

# report accuracy, precision, recall, and f1-score on both the training and testing split
train_stats = precision_recall_fscore_support(y_train_bi2, y_train_predict2, average='binary')
precision_train, recall_train, fscore_train = train_stats[0], train_stats[1], train_stats[2]

test_stats = precision_recall_fscore_support(y_test_bi2, y_test_predict2, average='binary')
precision_test, recall_test, fscore_test = test_stats[0], test_stats[1], test_stats[2]

print('The accuracy of training dataset: {:2.1%}'.format(perceptron.score(X_train_bi2, y_train_bi2)))
print('The precision of training dataset: {:2.1%}'.format(precision_train))
print('The recall of training dataset: {:2.1%}'.format(recall_train))
print('The fscore of training dataset: {:2.1%}\n'.format(fscore_train))

print('The accuracy of testing dataset: {:2.1%}'.format(perceptron.score(X_test_bi2, y_test_bi2)))
print('The precision of testing dataset: {:2.1%}'.format(precision_test))
print('The recall of testing dataset: {:2.1%}'.format(recall_test))
print('The fscore of testing dataset: {:2.1%}'.format(fscore_test))
# Out:
# The accuracy of training dataset: 82.0%
# The precision of training dataset: 83.2%
# The recall of training dataset: 80.1%
# The fscore of training dataset: 81.6%
#
# The accuracy of testing dataset: 81.8%
# The precision of testing dataset: 82.9%
# The recall of testing dataset: 80.1%
# The fscore of testing dataset: 81.5%

# %%
# use my own word2vec features to train a SVM
# refer to https://stackoverflow.com/questions/52008548/python-running-into-x-test-y-test-fit-errors
# for why with_mean should be set to False
svm = LinearSVC(random_state=1, max_iter=5000)
svm.fit(X_train_bi2, y_train_bi2)

y_train_predict2, y_test_predict2 = svm.predict(X_train_bi2), svm.predict(X_test_bi2)

# report accuracy, precision, recall, and f1-score on both the training and testing split
train_stats = precision_recall_fscore_support(y_train_bi2, y_train_predict2, average='binary')
precision_train, recall_train, fscore_train = train_stats[0], train_stats[1], train_stats[2]

test_stats = precision_recall_fscore_support(y_test_bi2, y_test_predict2, average='binary')
precision_test, recall_test, fscore_test = test_stats[0], test_stats[1], test_stats[2]

print('The accuracy of training dataset: {:2.1%}'.format(svm.score(X_train_bi2, y_train_bi2)))
print('The precision of training dataset: {:2.1%}'.format(precision_train))
print('The recall of training dataset: {:2.1%}'.format(recall_train))
print('The fscore of training dataset: {:2.1%}\n'.format(fscore_train))

print('The accuracy of testing dataset: {:2.1%}'.format(svm.score(X_test_bi2, y_test_bi2)))
print('The precision of testing dataset: {:2.1%}'.format(precision_test))
print('The recall of testing dataset: {:2.1%}'.format(recall_test))
print('The fscore of testing dataset: {:2.1%}'.format(fscore_test))
# Out:
# C:\Users\guanz\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# The accuracy of training dataset: 86.2%
# The precision of training dataset: 86.7%
# The recall of training dataset: 85.5%
# The fscore of training dataset: 86.1%
#
# The accuracy of testing dataset: 86.2%
# The precision of testing dataset: 86.6%
# The recall of testing dataset: 85.6%
# The fscore of testing dataset: 86.1%

# %% [markdown]
# ## 5. Feedforward Neural Networks

# %% [markdown]
# https://stanford.edu/~shervine/blog/pytorch-how-to-generate-data-parallel
# https://www.kaggle.com/code/mishra1993/pytorch-multi-layer-perceptron-mnist/notebook

# %%
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.nn.functional as F
import functools
from sklearn.metrics import accuracy_score

# %%
# Enable CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %%
# Hyperparameters
params = {'batch_size': 64,
          'shuffle': True,
          'num_workers': 0}
max_epochs = 50

# %%
# Override the Dataset class
class Dataset(Dataset):
    
    def __init__(self, list_IDs, labels):
        'Initialization'
        self.list_IDs = list_IDs
        self.labels = labels
    
    def __len__(self):
        'Denotes the total number of samples'
        return len(self.list_IDs)
    
    def __getitem__(self, index):
        'Generates one sample of data'
        # Select sample
        ID = self.list_IDs[index]
        
        # Load data and get label
        X = torch.load('data/' + ID + '.pt')
        y = self.labels[index]
        return X, y

# %% [markdown]
# ## Use the average of the Word2Vec vectors for each review as the input feature

# %% [markdown]
# ### Binary Classification

# %%
# Since my own word2vec model performed better than the pretrained one in terms
# of training simple models, I am gonna only use features generated from my own
# word2vec model to train the FNN/MLP model.

# Split the original training dataset into one training and one validation set
# The original labels are 1 and 2, and we need to convert them to 0 and 1,
# because in pytorch for binary classification, the labels should be 0 and 1.
train_IDs = {}
y_train = []
len_train_IDs = int(0.8 * len(X_train_bi2))
for i in range(len_train_IDs):
    train_IDs[i] = 'train_bi_' + str(i)
    y_train.append(y_train_bi2[i] - 1) # Convert label from 1 and 2 to 0 and 1

valid_IDs = {}
y_valid = []
len_valid_IDs = len(X_train_bi2) - len_train_IDs
for i in range(len_valid_IDs):
    valid_IDs[i] = 'valid_bi_' + str(i)
    y_valid.append(y_train_bi2[len(y_train) + i] - 1)
    
test_IDs = {}
len_test_IDs = len(X_test_bi2)
for i in range(len_test_IDs):
    test_IDs[i] = 'test_bi_' + str(i)

for i in range(len(train_IDs)):
    torch.save(X_train_bi2[i], 'data/' + train_IDs[i] + '.pt')

for i in range(len(valid_IDs)):
    torch.save(X_train_bi2[len(train_IDs) + i], 'data/' + valid_IDs[i] + '.pt')

for i in range(len(test_IDs)):
    torch.save(X_test_bi2[i], 'data/' + test_IDs[i] + '.pt')
# Out:
# "for i in range(len(train_IDs)):\n    torch.save(X_train_bi2[i], 'data/' + train_IDs[i] + '.pt')\n\nfor i in range(len(valid_IDs)):\n    torch.save(X_train_bi2[len(train_IDs) + i], 'data/' + valid_IDs[i] + '.pt')\n\nfor i in range(len(test_IDs)):\n    torch.save(X_test_bi2[i], 'data/' + test_IDs[i] + '.pt')"

# %%
# Generate training, validation and testing datasets
train_set = Dataset(train_IDs, y_train)
valid_set = Dataset(valid_IDs, y_valid)
test_set = Dataset(test_IDs, y_test_bi2)

# Generate dataloaders for the training, validation and testing datasets
train_loader = torch.utils.data.DataLoader(train_set, **params)
valid_loader = torch.utils.data.DataLoader(valid_set, **params)
test_loader = torch.utils.data.DataLoader(test_set, **params)

# %%
# Define the network architecture
class Net(nn.Module):
    def __init__(self, input_dim=300, output_dim=2, hidden_1=50, hidden_2=10):
        super(Net, self).__init__()
        # dimension of inputs
        self.input_dim = input_dim 
        # number of classes (2 for binary, 3 for ternary, ...)
        self.output_dim = output_dim
        # number of nodes in each hidden layer
        self.hidden_1 = hidden_1
        self.hidden_2 = hidden_2
        # linear layer (input --> hidden_1)
        self.fc1 = nn.Linear(self.input_dim, self.hidden_1)
        # linear layer (hidden_1 --> hidden_2)
        self.fc2 = nn.Linear(self.hidden_1, self.hidden_2)
        # linear layer (hidden_2 --> 2)
        self.fc3 = nn.Linear(self.hidden_2, self.output_dim)
        # dropout prevents overfitting of data
        self.dropout = nn.Dropout(0.2)
    
    def forward(self, x):
        # add the 1st hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer after the 1st hidden layer
        x = self.dropout(x)
        # add the 2nd hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer after the 2nd hidden layer
        x = self.dropout(x)
        # add output layer
        x = self.fc3(x)
        return x

# %%
# initialize the NN
model = Net()
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=300, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# specify cross entropy loss as loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
# train the network

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(max_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train() # prep model for training
    for data, target in train_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval() # prep model for evaluation
    for data, target in valid_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item()*data.size(0)
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.452994 	Validation Loss: 0.355458
# Validation loss decreased (inf --> 0.355458).  Saving model ...
# Epoch: 2 	Training Loss: 0.369756 	Validation Loss: 0.340425
# Validation loss decreased (0.355458 --> 0.340425).  Saving model ...
# Epoch: 3 	Training Loss: 0.355497 	Validation Loss: 0.334846
# Validation loss decreased (0.340425 --> 0.334846).  Saving model ...
# Epoch: 4 	Training Loss: 0.347683 	Validation Loss: 0.331255
# Validation loss decreased (0.334846 --> 0.331255).  Saving model ...
# Epoch: 5 	Training Loss: 0.340256 	Validation Loss: 0.327505
# Validation loss decreased (0.331255 --> 0.327505).  Saving model ...
# Epoch: 6 	Training Loss: 0.336159 	Validation Loss: 0.325886
# Validation loss decreased (0.327505 --> 0.325886).  Saving model ...
# Epoch: 7 	Training Loss: 0.331625 	Validation Loss: 0.322672
# Validation loss decreased (0.325886 --> 0.322672).  Saving model ...
# Epoch: 8 	Training Loss: 0.328647 	Validation Loss: 0.320394
# Validation loss decreased (0.322672 --> 0.320394).  Saving model ...
# Epoch: 9 	Training Loss: 0.325257 	Validation Loss: 0.319007
# Validation loss decreased (0.320394 --> 0.319007).  Saving model ...
# Epoch: 10 	Training Loss: 0.323011 	Validation Loss: 0.317322
# Validation loss decreased (0.319007 --> 0.317322).  Saving model ...
# Epoch: 11 	Training Loss: 0.320824 	Validation Loss: 0.314476
# Validation loss decreased (0.317322 --> 0.314476).  Saving model ...
# Epoch: 12 	Training Loss: 0.318471 	Validation Loss: 0.313669
# Validation loss decreased (0.314476 --> 0.313669).  Saving model ...
# Epoch: 13 	Training Loss: 0.315793 	Validation Loss: 0.312353
# Validation loss decreased (0.313669 --> 0.312353).  Saving model ...
# Epoch: 14 	Training Loss: 0.314689 	Validation Loss: 0.311008
# Validation loss decreased (0.312353 --> 0.311008).  Saving model ...
# Epoch: 15 	Training Loss: 0.312345 	Validation Loss: 0.310012
# Validation loss decreased (0.311008 --> 0.310012).  Saving model ...
# Epoch: 16 	Training Loss: 0.310894 	Validation Loss: 0.309442
# Validation loss decreased (0.310012 --> 0.309442).  Saving model ...
# Epoch: 17 	Training Loss: 0.309163 	Validation Loss: 0.309777
# Epoch: 18 	Training Loss: 0.307095 	Validation Loss: 0.309235
# Validation loss decreased (0.309442 --> 0.309235).  Saving model ...
# Epoch: 19 	Training Loss: 0.305997 	Validation Loss: 0.307125
# Validation loss decreased (0.309235 --> 0.307125).  Saving model ...
# Epoch: 20 	Training Loss: 0.304124 	Validation Loss: 0.307660
# Epoch: 21 	Training Loss: 0.304952 	Validation Loss: 0.306925
# Validation loss decreased (0.307125 --> 0.306925).  Saving model ...
# Epoch: 22 	Training Loss: 0.303322 	Validation Loss: 0.307034
# Epoch: 23 	Training Loss: 0.301553 	Validation Loss: 0.305461
# Validation loss decreased (0.306925 --> 0.305461).  Saving model ...
# Epoch: 24 	Training Loss: 0.300091 	Validation Loss: 0.307225
# Epoch: 25 	Training Loss: 0.298047 	Validation Loss: 0.305594
# Epoch: 26 	Training Loss: 0.297321 	Validation Loss: 0.305354
# Validation loss decreased (0.305461 --> 0.305354).  Saving model ...
# Epoch: 27 	Training Loss: 0.296684 	Validation Loss: 0.304776
# Validation loss decreased (0.305354 --> 0.304776).  Saving model ...
# Epoch: 28 	Training Loss: 0.295275 	Validation Loss: 0.305065
# Epoch: 29 	Training Loss: 0.294338 	Validation Loss: 0.305214
# Epoch: 30 	Training Loss: 0.292444 	Validation Loss: 0.307496
# Epoch: 31 	Training Loss: 0.291299 	Validation Loss: 0.306004
# Epoch: 32 	Training Loss: 0.291432 	Validation Loss: 0.305450
# Epoch: 33 	Training Loss: 0.289329 	Validation Loss: 0.305102
# Epoch: 34 	Training Loss: 0.290031 	Validation Loss: 0.304784
# Epoch: 35 	Training Loss: 0.289634 	Validation Loss: 0.304628
# Validation loss decreased (0.304776 --> 0.304628).  Saving model ...
# Epoch: 36 	Training Loss: 0.288699 	Validation Loss: 0.304697
# Epoch: 37 	Training Loss: 0.287121 	Validation Loss: 0.303869
# Validation loss decreased (0.304628 --> 0.303869).  Saving model ...
# Epoch: 38 	Training Loss: 0.287491 	Validation Loss: 0.304350
# Epoch: 39 	Training Loss: 0.286838 	Validation Loss: 0.304726
# Epoch: 40 	Training Loss: 0.285996 	Validation Loss: 0.304355
# Epoch: 41 	Training Loss: 0.285248 	Validation Loss: 0.304122
# Epoch: 42 	Training Loss: 0.283754 	Validation Loss: 0.304642
# Epoch: 43 	Training Loss: 0.283539 	Validation Loss: 0.305854
# Epoch: 44 	Training Loss: 0.282019 	Validation Loss: 0.304060
# Epoch: 45 	Training Loss: 0.281866 	Validation Loss: 0.305394
# Epoch: 46 	Training Loss: 0.281556 	Validation Loss: 0.304391
# Epoch: 47 	Training Loss: 0.280316 	Validation Loss: 0.304136
# Epoch: 48 	Training Loss: 0.280626 	Validation Loss: 0.307618
# Epoch: 49 	Training Loss: 0.280027 	Validation Loss: 0.305949
# Epoch: 50 	Training Loss: 0.278504 	Validation Loss: 0.304759

# %%
## Test the trained network
def predict(model, dataloader):
    prediction_list = []
    truth_list = []
    for i, batch in enumerate(dataloader):
        # batch[0] is X, and batch[1] is y
        outputs = model(batch[0])
        _, predicted = torch.max(outputs.data, 1)
        prediction_list.append(predicted)
        truth_list.append(batch[1])
    return prediction_list, truth_list

# %%
# Load model parameters from the trained model with the lowest validation loss
#model.load_state_dict(torch.load('model.pt'))

# Use the trained model to predict the testing samples
# The output is a list of tensors and a tensor consists of the predicted labels
# of a single batch of testing samples
predictions, truths = predict(model, test_loader)
# Convert predictions and truths from list of tensors to list of lists
predictions = [list(torch.Tensor.numpy(t)) for t in predictions]
truths = [list(torch.Tensor.numpy(t)) for t in truths]
# Convert predictions and truths from list of lists to a single list
predictions = functools.reduce(lambda a, b: a + b, predictions)
truths = functools.reduce(lambda a, b: a + b, truths)
# Convert predictions from (0, 1) to (1, 2)
predictions = [p + 1 for p in predictions]

# %%
# report accuracy, precision, recall, and f1-score on the testing dataset

test_stats = precision_recall_fscore_support(truths, predictions, average='binary')
precision_test, recall_test, fscore_test = test_stats[0], test_stats[1], test_stats[2]

print('The accuracy of testing dataset: {:2.1%}'.format(accuracy_score(truths, predictions)))
print('The precision of testing dataset: {:2.1%}'.format(precision_test))
print('The recall of testing dataset: {:2.1%}'.format(recall_test))
print('The fscore of testing dataset: {:2.1%}'.format(fscore_test))
# Out:
# The accuracy of testing dataset: 86.6%
# The precision of testing dataset: 87.0%
# The recall of testing dataset: 85.9%
# The fscore of testing dataset: 86.5%

# %% [markdown]
# ### Ternary Classification

# %%
# Since my own word2vec model performed better than the pretrained one in terms
# of training simple models, I am gonna only use features generated from my own
# word2vec model to train the FNN/MLP model.

# take the average word vectors of important words (i.e. non-stop words) in
# a review as the feature of a training sample
X_train_te2 = []
for x in X_train:
    wordveclist = []
    for word in x.split(' '):
        try:
            wordvec = model2[word]
            wordveclist.append(wordvec)
        except:
            pass
    X_train_te2.append(np.mean(wordveclist, axis=0))

# do the same to the testing dataset
X_test_te2 = []
for x in X_test:
    wordveclist = []
    for word in x.split(' '):
        try:
            wordvec = model2[word]
            wordveclist.append(wordvec)
        except:
            pass
    X_test_te2.append(np.mean(wordveclist, axis=0))
# Out:
# C:\Users\guanz\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\guanz\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# handle non-word-vector values in the dataset
# return the indices of word-vector values
wv_train = []
for i, x in enumerate(X_train_te2):
    try:
        len(x)
        wv_train.append(i)
    except:
        print(x)
        

wv_test = []
for i, x in enumerate(X_test_te2):
    try:
        len(x)
        wv_test.append(i)
    except:
        print(x)
        
# remove the non-word-vector values from the dataset
X_train_te2 = [X_train_te2[i] for i in wv_train]
X_test_te2 = [X_test_te2[i] for i in wv_test]
y_train_te2 = [y_train[i] for i in wv_train]
y_test_te2 = [y_test[i] for i in wv_test]
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
# Split the original training dataset into one training and one validation set
# The original labels are 1, 2 and 3, and we need to convert them to 0, 1 and 2,
# because in pytorch for multinomial classification with n classes, the labels
# should be 0, 1, ..., n-1.
train_IDs = {}
y_train = []
len_train_IDs = int(0.8 * len(X_train_te2))
for i in range(len_train_IDs):
    train_IDs[i] = 'train_te_' + str(i)
    y_train.append(y_train_te2[i] - 1) # Convert label from 1, 2 and 3 to 0, 1 and 2

valid_IDs = {}
y_valid = []
len_valid_IDs = len(X_train_te2) - len_train_IDs
for i in range(len_valid_IDs):
    valid_IDs[i] = 'valid_te_' + str(i)
    y_valid.append(y_train_te2[len(y_train) + i] - 1)
    
test_IDs = {}
len_test_IDs = len(X_test_te2)
for i in range(len_test_IDs):
    test_IDs[i] = 'test_te_' + str(i)

for i in range(len(train_IDs)):
    torch.save(X_train_te2[i], 'data/' + train_IDs[i] + '.pt')

for i in range(len(valid_IDs)):
    torch.save(X_train_te2[len(train_IDs) + i], 'data/' + valid_IDs[i] + '.pt')

for i in range(len(test_IDs)):
    torch.save(X_test_te2[i], 'data/' + test_IDs[i] + '.pt')

# %%
# Generate training, validation and testing datasets
train_set = Dataset(train_IDs, y_train)
valid_set = Dataset(valid_IDs, y_valid)
test_set = Dataset(test_IDs, y_test_te2)

# Generate dataloaders for the training, validation and testing datasets
train_loader = torch.utils.data.DataLoader(train_set, **params)
valid_loader = torch.utils.data.DataLoader(valid_set, **params)
test_loader = torch.utils.data.DataLoader(test_set, **params)

# %%
# Define the network architecture
# The only difference between the ternary and binary classifications is the
# dimension of the output layer (2 for binary and 3 for ternary)
'''class Net(nn.Module):
    def __init__(self, input_dim=300, output_dim=2, hidden_1=50, hidden_2=10):
        super(Net, self).__init__()
        # dimension of inputs
        self.input_dim = input_dim 
        # number of classes (2 for binary, 3 for ternary, ...)
        self.output_dim = output_dim
        # number of nodes in each hidden layer
        self.hidden_1 = hidden_1
        self.hidden_2 = hidden_2
        # linear layer (input --> hidden_1)
        self.fc1 = nn.Linear(self.input_dim, self.hidden_1)
        # linear layer (hidden_1 --> hidden_2)
        self.fc2 = nn.Linear(self.hidden_1, self.hidden_2)
        # linear layer (hidden_2 --> 2)
        self.fc3 = nn.Linear(self.hidden_2, self.output_dim)
        # dropout prevents overfitting of data
        self.dropout = nn.Dropout(0.2)
    
    def forward(self, x):
        # add the 1st hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer after the 1st hidden layer
        x = self.dropout(x)
        # add the 2nd hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer after the 2nd hidden layer
        x = self.dropout(x)
        # add output layer
        x = self.fc3(x)
        return x'''

# %%
# initialize the NN
# use model_te to be distinguishable from the binary model
model_te = Net(output_dim=3)
print(model_te)
# Out:
# Net(
#   (fc1): Linear(in_features=300, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=3, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# specify cross entropy loss as loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model_te.parameters(), lr=0.01)

# %%
# train the network

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(max_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model_te.train() # prep model for training
    for data, target in train_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_te(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model_te.eval() # prep model for evaluation
    for data, target in valid_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_te(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item()*data.size(0)
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model_te.state_dict(), 'model_te.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.829787 	Validation Loss: 0.740806
# Validation loss decreased (inf --> 0.740806).  Saving model ...
# Epoch: 2 	Training Loss: 0.752027 	Validation Loss: 0.722248
# Validation loss decreased (0.740806 --> 0.722248).  Saving model ...
# Epoch: 3 	Training Loss: 0.738544 	Validation Loss: 0.714632
# Validation loss decreased (0.722248 --> 0.714632).  Saving model ...
# Epoch: 4 	Training Loss: 0.729446 	Validation Loss: 0.707867
# Validation loss decreased (0.714632 --> 0.707867).  Saving model ...
# Epoch: 5 	Training Loss: 0.723327 	Validation Loss: 0.703287
# Validation loss decreased (0.707867 --> 0.703287).  Saving model ...
# Epoch: 6 	Training Loss: 0.718479 	Validation Loss: 0.699139
# Validation loss decreased (0.703287 --> 0.699139).  Saving model ...
# Epoch: 7 	Training Loss: 0.713546 	Validation Loss: 0.695830
# Validation loss decreased (0.699139 --> 0.695830).  Saving model ...
# Epoch: 8 	Training Loss: 0.710006 	Validation Loss: 0.694426
# Validation loss decreased (0.695830 --> 0.694426).  Saving model ...
# Epoch: 9 	Training Loss: 0.706183 	Validation Loss: 0.692254
# Validation loss decreased (0.694426 --> 0.692254).  Saving model ...
# Epoch: 10 	Training Loss: 0.704931 	Validation Loss: 0.690352
# Validation loss decreased (0.692254 --> 0.690352).  Saving model ...
# Epoch: 11 	Training Loss: 0.701536 	Validation Loss: 0.689008
# Validation loss decreased (0.690352 --> 0.689008).  Saving model ...
# Epoch: 12 	Training Loss: 0.698499 	Validation Loss: 0.688119
# Validation loss decreased (0.689008 --> 0.688119).  Saving model ...
# Epoch: 44 	Training Loss: 0.666750 	Validation Loss: 0.675942
# Epoch: 45 	Training Loss: 0.665647 	Validation Loss: 0.676681
# Epoch: 46 	Training Loss: 0.665081 	Validation Loss: 0.676658
# Epoch: 47 	Training Loss: 0.664896 	Validation Loss: 0.677686
# Epoch: 48 	Training Loss: 0.664789 	Validation Loss: 0.677047
# Epoch: 49 	Training Loss: 0.663816 	Validation Loss: 0.677444
# Epoch: 50 	Training Loss: 0.663543 	Validation Loss: 0.676510

# %%
# Test the trained network
# Use the same predict function as the binary case
def predict(model, dataloader):
    prediction_list = []
    truth_list = []
    for i, batch in enumerate(dataloader):
        # batch[0] is X, and batch[1] is y
        outputs = model(batch[0])
        _, predicted = torch.max(outputs.data, 1)
        prediction_list.append(predicted)
        truth_list.append(batch[1])
    return prediction_list, truth_list

# %%
# Load model parameters from the trained model with the lowest validation loss
model_te.load_state_dict(torch.load('model_te.pt'))

# Use the trained model to predict the testing samples
# The output is a list of tensors and a tensor consists of the predicted labels
# of a single batch of testing samples
predictions, truths = predict(model_te, test_loader)
# Convert predictions and truths from list of tensors to list of lists
predictions = [list(torch.Tensor.numpy(t)) for t in predictions]
truths = [list(torch.Tensor.numpy(t)) for t in truths]
# Convert predictions and truths from list of lists to a single list
predictions = functools.reduce(lambda a, b: a + b, predictions)
truths = functools.reduce(lambda a, b: a + b, truths)
# Convert predictions from (0, 1, 2) to (1, 2, 3)
predictions = [p + 1 for p in predictions]

# %%
# report accuracy, precision, recall, and f1-score on the testing dataset

test_stats = precision_recall_fscore_support(truths, predictions, average='micro')
precision_test, recall_test, fscore_test = test_stats[0], test_stats[1], test_stats[2]

print('The accuracy of testing dataset: {:2.1%}'.format(accuracy_score(truths, predictions)))
print('The precision of testing dataset: {:2.1%}'.format(precision_test))
print('The recall of testing dataset: {:2.1%}'.format(recall_test))
print('The fscore of testing dataset: {:2.1%}'.format(fscore_test))
# Out:
# The accuracy of testing dataset: 71.1%
# The precision of testing dataset: 71.1%
# The recall of testing dataset: 71.1%
# The fscore of testing dataset: 71.1%

# %% [markdown]
# ## Use the concatenation of the first 10 Word2Vec vectors for each review as the input feature

# %% [markdown]
# ### Binary Classification

# %%
# The function below cannot be applied to the training and testing sets due to
# the memory limitation, so I am gonna use a for loop to append words for every
# review in the datasets.

# define an appendWords function to append the word vectors of the first 10 words
'''def appendWords(s):
    ls = s.split(' ')
    wordveclist = []
    for i in range(10):
        try:
            wordveclist.append(list(model2[ls[i]]))
        except:
            pass
    return wordveclist

# append the word vectors of first 10 words together for all the reviews in both the training and testing sets
X_train_bi2 = [appendWords(x) for x in X_train_bi]
X_test_bi2 = [appendWords(x) for x in X_test_bi]'''

# Since my own word2vec model performed better than the pretrained one in terms
# of training simple models, I am gonna only use features generated from my own
# word2vec model to train the FNN/MLP model.
# concatenate the first 10 word vectors of important words (i.e. non-stop words)
# in a review as the feature of a training sample
X_train_bi2 = []
for x in X_train_bi:
    wordveclist = []
    first_10_words = x.split(' ')[:10]
    for word in first_10_words:
        try:
            wordvec = list(model2[word])
            wordveclist.append(wordvec)
        except:
            pass
            
    X_train_bi2.append(wordveclist)

# do the same to the testing dataset
X_test_bi2 = []
for x in X_test_bi:
    wordveclist = []
    first_10_words = x.split(' ')[:10]
    for word in first_10_words:
        try:
            wordvec = list(model2[word])
            wordveclist.append(wordvec)
        except:
            pass
            
    X_test_bi2.append(wordveclist)

# %%
# define a function that adds padding to the reviews with length less than 10 words
def add_padding(x):
    padding = [0 for _ in range(300)]
    if len(x) < 10:
        for i in range(10 - len(x)):
            x.append(padding)
    return x

# add paddings
X_train_bi2 = [add_padding(x) for x in X_train_bi2]
X_test_bi2 = [add_padding(x) for x in X_test_bi2]

# %%
# reshape the word vector of a review from (10, 300) to (3000,)
X_train_bi2 = [functools.reduce(lambda a, b: a + b, x) for x in X_train_bi2]
X_test_bi2 = [functools.reduce(lambda a, b: a + b, x) for x in X_test_bi2]

# %%
# SKIP this step because all non-word-vectors are padded with 0's.
# handle non-word-vector values in the dataset
# return the indices of word-vector values
'''wv_train = []
for i, x in enumerate(X_train_bi2):
    try:
        len(x)
        wv_train.append(i)
    except:
        print(x)
        

wv_test = []
for i, x in enumerate(X_test_bi2):
    try:
        len(x)
        wv_test.append(i)
    except:
        print(x)
        
# remove the non-word-vector values from the dataset
X_train_bi2 = [X_train_bi2[i] for i in wv_train]
X_test_bi2 = [X_test_bi2[i] for i in wv_test]
y_train_bi2 = [y_train_bi[i] for i in wv_train]
y_test_bi2 = [y_test_bi[i] for i in wv_test]'''

# %%
# Split the original training dataset into one training and one validation set
# The original labels are 1 and 2, and we need to convert them to 0 and 1,
# because in pytorch for binary classification, the labels should be 0 and 1.
len_train = int(0.8 * len(X_train_bi2))
X_train, y_train = X_train_bi2[:len_train], []
for i in range(len_train):
    y_train.append(y_train_bi[i] - 1) # Convert label from 1 and 2 to 0 and 1

len_valid = len(X_train_bi2) - len_train
X_valid, y_valid = X_train_bi2[len_train:], []
for i in range(len_valid):
    y_valid.append(y_train_bi[len_train + i] - 1)

X_test, y_test = X_test_bi2, y_test_bi

# %%
# Override the Dataset class
class Dataset(Dataset):
    
    def __init__(self, features, labels):
        'Initialization'
        self.features = features
        self.labels = labels
    
    def __len__(self):
        'Denotes the total number of samples'
        return len(self.features)
    
    def __getitem__(self, index):
        'Generates one sample of data'
        # Select sample
        X = torch.tensor(self.features[index])
        y = self.labels[index]
        
        return X, y

# %%
# Generate training, validation and testing datasets
train_set = Dataset(X_train, y_train)
valid_set = Dataset(X_valid, y_valid)
test_set = Dataset(X_test, y_test)

# Generate dataloaders for the training, validation and testing datasets
train_loader = torch.utils.data.DataLoader(train_set, **params)
valid_loader = torch.utils.data.DataLoader(valid_set, **params)
test_loader = torch.utils.data.DataLoader(test_set, **params)

# %%
# Define the network architecture
# The same as before
class Net(nn.Module):
    def __init__(self, input_dim=300, output_dim=2, hidden_1=50, hidden_2=10):
        super(Net, self).__init__()
        # dimension of inputs
        self.input_dim = input_dim 
        # number of classes (2 for binary, 3 for ternary, ...)
        self.output_dim = output_dim
        # number of nodes in each hidden layer
        self.hidden_1 = hidden_1
        self.hidden_2 = hidden_2
        # linear layer (input --> hidden_1)
        self.fc1 = nn.Linear(self.input_dim, self.hidden_1)
        # linear layer (hidden_1 --> hidden_2)
        self.fc2 = nn.Linear(self.hidden_1, self.hidden_2)
        # linear layer (hidden_2 --> 2)
        self.fc3 = nn.Linear(self.hidden_2, self.output_dim)
        # dropout prevents overfitting of data
        self.dropout = nn.Dropout(0.2)
    
    def forward(self, x):
        # add the 1st hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer after the 1st hidden layer
        x = self.dropout(x)
        # add the 2nd hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer after the 2nd hidden layer
        x = self.dropout(x)
        # add output layer
        x = self.fc3(x)
        return x

# %%
# initialize the NN
model_bi2 = Net(input_dim=3000)
print(model_bi2)
# Out:
# Net(
#   (fc1): Linear(in_features=3000, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# specify cross entropy loss as loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model_bi2.parameters(), lr=0.01)

# %%
# train the network

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(max_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model_bi2.train() # prep model for training
    for data, target in train_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_bi2(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model_bi2.eval() # prep model for evaluation
    for data, target in valid_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_bi2(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item()*data.size(0)
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model_bi2.state_dict(), 'model_bi2.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.486026 	Validation Loss: 0.436483
# Validation loss decreased (inf --> 0.436483).  Saving model ...
# Epoch: 2 	Training Loss: 0.434841 	Validation Loss: 0.426167
# Validation loss decreased (0.436483 --> 0.426167).  Saving model ...
# Epoch: 3 	Training Loss: 0.414335 	Validation Loss: 0.422378
# Validation loss decreased (0.426167 --> 0.422378).  Saving model ...
# Epoch: 4 	Training Loss: 0.398915 	Validation Loss: 0.420361
# Validation loss decreased (0.422378 --> 0.420361).  Saving model ...
# Epoch: 5 	Training Loss: 0.385116 	Validation Loss: 0.421389
# Epoch: 6 	Training Loss: 0.371048 	Validation Loss: 0.424653
# Epoch: 7 	Training Loss: 0.358265 	Validation Loss: 0.427968
# Epoch: 8 	Training Loss: 0.346016 	Validation Loss: 0.434038
# Epoch: 9 	Training Loss: 0.332788 	Validation Loss: 0.442058
# Epoch: 10 	Training Loss: 0.318841 	Validation Loss: 0.451648
# Epoch: 11 	Training Loss: 0.308052 	Validation Loss: 0.461122

# %%
# Test the trained network
# The same as before
def predict(model, dataloader):
    prediction_list = []
    truth_list = []
    for i, batch in enumerate(dataloader):
        # batch[0] is X, and batch[1] is y
        outputs = model(batch[0])
        _, predicted = torch.max(outputs.data, 1)
        prediction_list.append(predicted)
        truth_list.append(batch[1])
    return prediction_list, truth_list

# %%
# Load model parameters from the trained model with the lowest validation loss
model_bi2.load_state_dict(torch.load('model_bi2.pt'))

# Use the trained model to predict the testing samples
# The output is a list of tensors and a tensor consists of the predicted labels
# of a single batch of testing samples
predictions, truths = predict(model_bi2, test_loader)
# Convert predictions and truths from list of tensors to list of lists
predictions = [list(torch.Tensor.numpy(t)) for t in predictions]
truths = [list(torch.Tensor.numpy(t)) for t in truths]
# Convert predictions and truths from list of lists to a single list
predictions = functools.reduce(lambda a, b: a + b, predictions)
truths = functools.reduce(lambda a, b: a + b, truths)
# Convert predictions from (0, 1) to (1, 2)
predictions = [p + 1 for p in predictions]

# %%
# report accuracy, precision, recall, and f1-score on the testing dataset

test_stats = precision_recall_fscore_support(truths, predictions, average='binary')
precision_test, recall_test, fscore_test = test_stats[0], test_stats[1], test_stats[2]

print('The accuracy of testing dataset: {:2.1%}'.format(accuracy_score(truths, predictions)))
print('The precision of testing dataset: {:2.1%}'.format(precision_test))
print('The recall of testing dataset: {:2.1%}'.format(recall_test))
print('The fscore of testing dataset: {:2.1%}'.format(fscore_test))
# Out:
# The accuracy of testing dataset: 79.9%
# The precision of testing dataset: 80.3%
# The recall of testing dataset: 79.1%
# The fscore of testing dataset: 79.7%

# %% [markdown]
# ## 6. Recurrent Neural Networks

# %%
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.nn.functional as F
import functools
from sklearn.metrics import accuracy_score

# %%
# Enable CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ### Binary Classification

# %%
X_train_bi
# Out:
# ['fry pan look good ha sticking problem hard clean yellow stain ',
#  'like container except doe leak took one star still good nondrippy food two large boiled egg fit easily one container work well good dab hummus carrot stick frozen ice pack last several hour best insulated bag price high one containerthat vendor may include shipping help available local store amazon vendor price varycheck grand total price picture shown make lid seem hingedits',
#  'love enhanced flavor water many recipe combination cant wait try',
#  'thing worked well first wash machine sealant came loose water became trapped two layer guess hand wash want keep month',
#  'sushi dish wonderful stoneware solid durable piece well made design doe rough texture may bother people like chopstick basic well crafted functional overall great set couple like eat sushi japanese cuisine',
#  'overpricedto smalldid keep drink cold',
#  'cool great money convenient way pop open ice cold nice job island dog',
#  'work well look great counter complaint center carousel get dusty crumby cant fit hand cup holder wipe',
#  'ordered keurig thought price wa unbeatable well wa definitely good true filter work ok yet see major difference performance brand keurig name brand however crucial coffee filter packed individually clear plastic plastic wrapped pair low price worth since need switched every week however think ill keep eye local store keurig filter sale',
#  'really like little slow cooker arrived little dinged wasnt really visible got thing counter didnt award star owned many slow cooker life tell one great choice work amazingly well feeding people fit lot might think also super easy clean evencooking doesnt overheat like last one actual crock pot branded cooker id buy sure would also great gift wedding college student size easy use functionality may fanciest slow cooker block solid highquality sensible buy',
#  'used one time worked well wa pleased used second time several didnt read accurately threw',
#  'happy picture received misleading wanted color shown got color',
#  'needed new coffee maker wanted option nearly fully automatic unit unit fit bill unit make great coffee ha problemsthe goodbad unit doe force clean coffee maker often would normally likely good thing still annoying',
#  'bought son last year love ha something left lunch box end school day still cold put yogurt back fridge sixth grade thing wish boy design',
#  'product work well wa little difficult slide bracket would better came illustrated instruction',
#  'love blender health fitness business monthly prize giveaway totally worth money plug anywhere',
#  'work well one handed grinder top silver sleeve detachesslips acrylic cylinder aesthetic issue though ill either silicone leave together',
#  'super cute must buy',
#  'knife sharpener president usa toy boy good',
#  'serve purpose however flexible enough fit correctly bow one guard cannot get sit correctly edge stove flexible material would work much better threw one side away',
#  'received different box include coffee oil remover product info photo updated',
#  'scoop dollar tree work better must remove rubber handle clean lever jumped track st use scoop really low quality oneida scoop way better love oneida scoop',
#  'useful container purpose storagebut unfortunately fit cooker measurement suitable cooker',
#  'bought big box store returned within week first one first day said add water water reservoir wa full push spring water reservoir seemed trick sound like someone hand pumping water slowly coffee unplugged first one night plugged back morning coffee said add water water reservoir wa full also said wait water heated water started coming reservoir wa empty really doe need waterlolall want damn cup coffee could start day good note',
#  'spoon somewhat flimsy bend easily mine came cardboard packaging stuck one took little effort get scraped',
#  'wasnt sure id want deli slicer selected model wa pretty cheapthe trick cooking good roast slicing sear bejeezus keep juice cooking use superheated cast iron pan get every possible surface seared almost done cooking resist urge cut meat see cooked thats disaster release juice use meat thermometer instead looking degree nice medium rare bit overdone way end nice reddish roast beef yummy sandwich work week',
#  'unseeded much smaller expected',
#  'first day product broke two plastic piece hold top white part press chop food literally broke first time used dont want go hassle returning poorly made trash',
#  'use knife every day cutting fruit veggie handle nice grippy ha started rust blade meet handle recommend new buyer clean dry immediately use prevent rust forming otherwise great knife',
#  'paula dean put name quality product never wonder whether getting pay',
#  'lightweight stamped steelwas impression ha cast iron pound weight boxdinky',
#  'please self favor buy item toaster oven burn bottom everything heat toaster toast bread bagel well still ha yet toast anything u run toaster time never toastbrown wa shocked item would bad hamilton beach good brand something obviously wrong production product forget purchasing one wa zero star option product would given zero',
#  'jokari soda dispenser work well work yes stop working sure happens mostly work great keep soda loosing fizz propels soda sparkling water glass soda mix whatever else glass liquid level bottle low shake bottle order build enough pressure expel soda big deal trick work well ive found best remove white cap ring remains top plastic bottle unscrew cap cut ring seems block jokari screwing tight enough onto bottle',
#  'need new basting brush im glad got brush hold oil whatever else using easy clean',
#  'great knife glad bought handle feel good doesnt slip hand weight nice',
#  'count time fine actual alarm ring puny brief wouldnt hear unless standing right next',
#  'good',
#  'love appliancethank kitchenaide incomplete instruction',
#  'knew going low quality wanted hungry caterpillar favor bought anyway bottle small bubble blower packaged separately bottle blower float around separately favor bag one package purchased fluid leaked sticker image around bottle wa soaked one even ripped would recommend',
#  'ordered oz shaker bottle received oz bottle product good wrong size gave low review',
#  'fourth capresso grind brew far away worst one least keep coffee hot unlike model make mess counter since ground basket always leak water ground around plastic basket infrequent occasion grind correct amount coffee dripstopper actually stop drip onto hot plate manages drip water inside hotplate area also make mess spilled water ground coffee remove filter cleaning find difficult believe anyone could bad job designing coffeemaker fail overall poor design work badly ive returned one bought refurbished earlier model ',
#  'thanks',
#  'great product',
#  'device doe indeed hold disc blade lock closedthis mean wish move box around full easily slice hand open blade protrude underneath examine product image ha blade disc examine image product full notice part blade disc obscured interior plastic hidden bit exposed underside',
#  'pretty tiny relatively expensive compared gift tag unless looking small tag would pas also need purchase type ribbon string attach gift making even expensive',
#  'board arrived reviewed others doe need sanded price size ok wanted',
#  'st time wife used thing wa thanksgiving turkey dinner temp reading said turkey wa done let bird sit asked carve wa totaly pink inside still put cut piece back oven finish cooking wa dry bone crispy best place thermometer',
#  'thrilled opener son aspergers wa never able use electric opener regular manual opener decided get hoped hed able use wa really happy first attempt opened im extremely pleased product highly recommend',
#  'love',
#  'really enjoy using tool sculpture class nicely designed',
#  'never used juicer though saw many first timer easy use easy clean le minute dry refuse lot juice highly recommend',
#  'purchased singleserving coffee maker awhile ago found burnt available pod flavor got pod maker much enjoyed able make pod however product doesnt last long since read several review site problem pod maker worked great month heating element would longer heat called number manual several time got answering machine every time left message never get response refuse spend another dollar product doesnt even last year however find way continue making pod took product apart removed heating element electronics plastic base part need keep use small travel size iron heat pod seal well better original heating element want use iron without water avoid get pod wet sealing note product fail little adjustment still use make favorite coffee pod',
#  'like set ha circle center cut nice metal pretty sturdy adult use made nice cut pi pie crust yes top crust wa used far hand washed seem like theyll hold',
#  'lunch bag easy clean ha held really well far reason gave star little bit tricky getting food item fit odd shape',
#  'loved looked loved price toasted unevenly bottom toast would burn even lowest setting send back',
#  'pretty cool unique skull lover',
#  'faucet sprayer really nice especially large deep sink smaller shallow sink kinda get way',
#  'ok nothing special',
#  'nice',
#  'paper better leaf ground pot hassle clean',
#  'great gift wine enthusiast someone enjoys conversation piece home arc wooden modest design one end compliment home decor appeal men woman arc stand hard flat surface problem noticed hole wa small one bottle wine fit trying find gift wine enthusiast looking something unique perfect gift',
#  'received order promptly gasket work fine',
#  'ordered cut flower delivered within day relative hospital flower arrive called orchid said problem fedex contacted fedex said orchid give shipment time called back said weve really busy went day later essentially lied first admitted really happened never thought notify delay meanwhile relative waiting day flower didnt arrive eventually delivered dont understand orchid didnt sense least tell delay could let relative know irresponsible unprofessional',
#  'wanted try wa le thought wa worth tryit hurths hand badly twist crush garlicit need cut small piece crushed might well chop crush knifetotally bad purchase waste time returning would cost goign trash',
#  'love',
#  'worked normally around year ago tare function failed workedthen would switch pressing button secondsand secondsit seems almost builtin obsolescence ha written software im sure cannot true',
#  'already used several time great',
#  'ordered lid thats clearly listed orange received green pumpkin lid label product say pumpkin lid green color plain ugly like charles viancin lid bottle stopper quality great excellent job come green pumpkin lid acceptable especially listed orange',
#  'god',
#  'got year different brand finally got stained came aparteven cooked water several time see would workno wa going send back wa past time return reread review one said anything awful smell guess bought',
#  'loved sleek look banana hung however holder welded bowl banana holder constantly fellvery annoying also loved deep bowl fit lot fruit found side bowl bruise fruit easily',
#  'great carrier reviewer said make sure youre closing correctly make decent seal however doesnt exactly traction make special little stopper cake little smaller side container wont slide around',
#  'good stewing pot good shape size quality wish cover would tight pot',
#  'wonderful product happy purchase',
#  'advertised removable cooking surface great improvement older style',
#  'best travel cup ever used toddler spill proof easy clean easy use',
#  'girl friend like alot',
#  'im amending review since feeling product changed wa solid purchase wa great kid easy clean broke one child different color purchased different store even broke within month kid unable get water spout even straw wa firmly connected sucking air worth money opinion larger version still work well year im sure type wa bad',
#  'work great',
#  'used last night first time carving tgiving turkey stink handle slick grease turkey nearly impossible hold hand slip forward nearly impossible push button use two hand hold le desirable plus barely enough power cut real small ligament overall worth time make slippery plastic nothing provide sure nonslip gripping surface beyond',
#  ' start havent used yet however package seemed like sturdy utensil cook pleased far',
#  'awesome',
#  'realize kit class instruction wouldnt hurt pink foam wa discolored yellowish arrived unless kit class waste money everything cheaply made',
#  'working well like glass lid clean well seem heat well midsize pan little larger unit use small use larger one still work well problem food sticking fry pan dont use lot',
#  'box cute pricey keep kid interest sure',
#  'bought glass twice first time broke thought hmmm replace husband bought set broke hand wa washing rim hit wedding band thin rock gold ring tipped rim glass chattered piece replacing anything anymorei afraid use glass broke within week receiving purchase upset cheap glass used',
#  'wont repeat everyone else ha raved little appliance didnt want skip star review either learning curve short one cant really cook meat cook put back bit make mushy potato extended time habit cooking much longer beef roast like chunk heavendont afraid try nothing dangerous like old school pc total freedom watching oven water logged crock pot food awesome',
#  'could give half star would received base top cutting assembly gasket wa waste money cant even use',
#  'doesnt really work ice ball get center line make ice ball look deformed',
#  'worked great three month worked liked much bought another hoping first wa fluke wasnt im disappointed went aerolatte frother work wonderfully',
#  'cleancaf cleaner came purchase hamilton beach brew station coffeemaker good job using ever since price delivery get amazon great would advise people looking good coffee maker cleaner use cleancaf cleaner buy amazon',
#  'girlfriend love toaster excellent quality price agree look handsome well slanted opening definitely make easier retrieve small piece bread extra lift function work great every toaster',
#  'although beautiful look initially appeared well made lid broke within hour proper handling secondary simply taking pot clean seems way contact company see replacement lid available im unfortunately going give product two star rating disappointed',
#  'wa handwashing bottle kitchen top half bottle abruptly broke piece didnt shatter came piece causing cut finger wlots bloodit look fancy pretty would recommend bottle due safety issue',
#  'doe fit doe work well cheep material wanna buy waiting nothing day',
#  'good',
#  'rice cooker several year use month look brand new never immersed water mistreated way today pouring rice stainless steel pot unit plugged warm touched rim received substantial electrical shock hand yet added water wa water nearby floor outlet checked meanwhile aware stainless steel pot make easier conduct electricity nonstick pot',
#  'great idea didnt heat enough keep coffee warm usb port right corner desk keep coffee cup wa greatas long coffee cup thing lightweight kept moving around falling desk easy retrieve wa plugged computer annoying onof light small hard see onoff switch unit good didnt keep coffee warm replace',
#  'kitchen tool small create chopped salad',
#  'save much time one container doe whipped cream chia pudding lid go straightaway fridge also pured soup smooth bchamel disaster find reaching whisk attachment could sturdy get job done albeit attention part wa lifesaver sesame paste wa separated wa midway making hummus',
#  'really didnt get boxcutter rattling heardreceived dish broken terribly packaged airfilled plastic bag used padding sent back refund still havent heard anything yet though seen quite review customer received broken dish guess best buy dish brickandmortars',
#  'let natural oil making coffee also dont like go buy paper filter',
#  'wa perfect addition husband garage ha held great sturdy make great stocking stuffer small gift father day',
#  'bit bulky',
#  'pretty work hot heavy pan silicone time thickness cheaper pad',
#  'amazing work look great toooooooo',
#  'husband gave kenwood mixer christmas past year put test made cake call cream cheese butter tossed mixer bowl cold ha problem mixing happy mixer easy clean well',
#  'say spoon nice weight really shiny kinda look like real silver wanted decent set soup spoon fit bill',
#  'coffee maker month patient person actually withstood longbtw older version cuisinart dgbbc grindandbrew thermal carafe way goand wa extremely sad went college child wa year old still working even chipped plastic spout',
#  'dont like large fault nordic ware error investigating prior purcahsing',
#  'bought meat grinder three item heartland americathe meat grinder lasted hour somthing broke insidei also bought clock said wa made solid wood wa really made pressed cardboard sprayed type clear plastic junkand air cleaner never worked day onewhen sent back order took long time get refund charged alot shippingdo buy vendor',
#  'daughter loved bumble snowman fan amazon delivered quickly time holiday',
#  'tall expected straw little smaller typicaly cup overall ok wa hard find star buck store thought wa little bazzar',
#  'burned press handle roll unless tightly screwed also wooden handle doe extend support burned unless careful pick also rust unless carefully seasoned dried use work well anyone else using would throw want someone getting burn scar arm',
#  'quick handy great want quick egg breakfast work travelling complaint egg stick red cup bit horrible would nicer didnt stick',
#  'little machine seems well made simple use cut approximately noodle something similar regular spaghetti noodle new device im learn get width pasta right start running press side get thickness want also end spanning width unit matter efficient noodle cutting case first thing made wa stuffed ravioli ravioli roller obviously getting full width pasta make le ravioli roller operation get ravioli possible thats matter practicethe complaint far cleaning unit poorly described mechanically inclined cannot figure far especially following direction still cant get unit apart clean roller direction picturefigures manual give enough detail figure im sure looking youtube like real instruction clean component manual individual work company provide customer take away one star',
#  'outside stay cool use darkness guide generate guide desired darkness slot long enough bread slice even lift feature english muffin hard retrieve would buy',
#  'high hope armoire given already matching desk wa hesistant buy negative review desk wa pain put together also thought advice received previous reviewer iepredrilling use wood gluewould address problem might encounter turn product really well designed average person assemble herhis unless especially skilled improving flimsy product someone life like enough go ordeal working iti would recommend looking solid piece furniture bad quite attractive worried going collapse given momenteven additional precaution helper took',
#  'good',
#  ' shippingi going end returning rust issue guess wa bent slightly shipping causing rubbing second popper first wa completely bent inward shipping couldnt turn handle',
#  'waiting several week finally received grinder pollen screen wa broken reckon get pay',
#  'coaster rough actually scratched wood desk bought protect unless using surface cant get scratched would recommend going smootherlighter coaster',
#  'thin papershave use two still leak happy',
#  'got hot saw beautiful hot hot little small anyway hot good',
#  'like reviewer broke six month occasional use well technically wa broken arrival since wouldnt turn traced first fault improperly assembled power cord wa able fix six month occasional use used time broke wouldnt turn troubleshooting traced problem defect timer switch love multimeter warranty joke time ship broken one pay shipping refurbished replacement nearl paid brand new one went trash ill avoiding rival daniel',
#  'portion pitcher lid abuts handlea slice lid angled sharp edgejust cut thumb like steak knife product completely unsafe one especially child operating product lid design holiday plan wrapping present preparing food exercising gym playing game become difficult impossible thanks lacerated thumb pitcher dangerous lid construction',
#  'cupcake holder ordinary best certainly overpriced color vibrant double even arent colorful depicted wont using',
#  'cheaply made product body unit appears aluminum stainless steal quite light unit doe sit flush table wobble lid difficult twist green light signifying coffee done brewing go coffee stop brewing',
#  'sticky nice price',
#  'knife terribly dull decided purchase presto ha worked well didnt want spend bundle money didnt want buy new knife little machine great sharpened knife easily really careful cut im happy',
#  'wa thrilled find curtain already coordinating valance olive kid line however arrived match frustrating emailed seller said two different color check pattern line crazy would even known said could return within day wa already day past arrival date wa way since hadnt purchased valance site seller wa unwilling accomodate difference standard return policy set unmatching curtain valance disappointing',
#  'easytoclean beater great lowest speed mixer fast even deep bowl batter fly everywhere counter top wall old rival handheld beater bought target wa better wish could return day return window ha lapsed',
#  'easy usereproducible resultseasy clean short cord understandable',
#  'le buck star strainer one replaced wa probably year old wood handle nice size small item metal handle also nice mesh thick used wine beer making overall nice size kitchen stainless steel seems pretty solid',
#  'almost drove crazy trying find new coffee machine original hamilton beach brewstation started leaking year daily use review coffee machine generally horrible chose one simply brand fact review psyche buying iti ditched machine awhile thing liked wa clock water pouring became annoying coffee tasted worse worse even cleaning eventually developed odd musty odor even though wa rinsed dried daily washed twice per week enough using french press impressed product especially price',
#  'love rox ice ball long lasting fun conversation starter probably purchase several large groupspriscilla',
#  'worst opener ever made plastic hence light therefore tilt forward trying place opened meshing cutter frustrating experience take two three time get right poor product',
#  'two year worked loved buy another may happen seems like everything buy doe last sad',
#  'vine program offered oxo good grip mini santoku knife got lot say apply nice knife price sharp comfortable hold course grip knife individual least make easy handle packaging get idea suit notthe blade inch wide widest point tang doe extend handle im giving four star instead five terrific knife doubt lot longevity still price shouldnt expect forever knife would great starter knife though',
#  'top shaker thin non polished metal wa also glued rip paper one shaker topsdont check thing shippingi seen better quality shaker dollar store',
#  'product indicated wa bosh tassimo machine ended returning getting money back',
#  'product great love however caution let back mat get wet water wa spilled went mat get new one however im aware time covered back foil case happened product great however amount paper put pack rediculous wasteful foot paper straightened way much needed',
#  'love size wish lined something really dislike feel inside super cute though adding previous review changed one star tried taking pan degree oven drop pan heat resistant enough',
#  'purchased month ago yesterday opened door clip spice jar fell luckily plastic seemed like reasonable way add storage working would recommend something permanent store spice',
#  'digital scale easy use adjust whatever unit measurement prefer light weight fairly small came two battery',
#  'made great coffee time worked stopped heating le week coffeemaker would turn heating pad would',
#  'yes little hole capture tiniest kitchen waste also double strainer pouring something jar',
#  'broke dang quick bought something else',
#  'bought machine size would fit appliance garage however order narrow loaf pan elongated hence two paddle instead one result poor kneading dough get repeatedly torn tearing gluten strand theyre forming least conjecture work ok make large amount dough cant make small loaf smallish amount pizza dough tried baking machine doubt would work well either lift lid get dough first rise usually lopsided expensive one wa fine job one however started schooching counter kneading finally smashed floor good luck bread machine caveat bake bread family get used time week',
#  'use scale five time week convenient measuring either pound ounce kilogram love fact set f put container highly recommended',
#  'smaller thought cake stuck alot pan ok seller wa excellent',
#  'better thought really nice',
#  'bought one sell pet jersey maker name first one arrived broken got new one used decent job tonight went use second time tray cracked every one didnt check unit took treat idea happened hand use jerky gun time terrific luckily got sale already excaliber dehydrator wa much money worth every penny got one back made much fit excaliber use gun time love sold separately break ill buy anothermy recommendation think want dehydrator start cheap one want good one bite bullet go best',
#  'product ha temperature setting slow cooking feature say dial setting deep frying enclosed instruction manual also give direction use deep fryer manual also say leave unit hour slow cooking take hour recommend item concept slow cooker steamer deep fryer etc one unit great idea unit doe advertisedi disappointed misleading description requested replacement wa advertised second unit wa identical returned alsonow waiting refund',
#  'love live mojave desert water great',
#  'im going write long review thing water filter work fine start using early january taste difference really rather boil water whatever taste design get rust believe saw someone else posting photo rust guess got photo fyi got first one threw away second one might trash dont buy one word rust wa buy another water filter type without temp rod inside unbelievable',
#  'expected smoother operation calphalon got hard lock unlock',
#  'ok',
#  'although material heavy first joyce chen kettle product good id',
#  'used stop working weight give item different recommend one',
#  'corkscrew cutter came time company emailed personally check see everything wa wanted didnt expect kind service small orderworks great exactly need isnt lot say corkscrew customer service keep coming back',
#  'love thing shout filling grinding cup grinding emptying easy doe spill shake level ground coffee grinding opening also love set measure grind size push button doe thing perfectly consistently cleanup also breeze device ha exceeded expectation around one favorite purchase',
#  'deal folk bought unit month ago recently made best coffee ever tasted period loved loved whole thing made stainless steel plastic aluminum touch coffee stopped working',
#  'ordered different color color good packaging wa awful one package ripped open multiple napkin jammed package dont know happened make question quality fabric quite thin wrinkle terribly need lot ironing way much maintenance napkin',
#  'love dont constantly refer computer convert ingredient american measurement baking get lot recipe australian british cooking site like sortedfoodcom make cooking baking lot easier',
#  'oven died month light use great work prepare sudden oven death syndrome disappointing widely recommended product buy another breville faux premium review true prepared replace year buy another brand cookscom recommends theyre wrong',
#  'wa second panasonic microwave inverter technology love softens butter like champ first one died five year liked much ignored failure attributing randomness well two year model ha failed completely warning blank control screen conclude reliability problemso without breakdown using would given star rating two panny oven failed give first ever one star review',
#  'needed',
#  'bowl measure wide including crab handlethe actuall bowl measure wide height hold exactly cup water brim dip one gave two star cute little bowl mean little',
#  'good idea doesnt last long enough',
#  'cant complainits cuplol price wa right',
#  'cuisinart hase worst customerservice dept ever refused honor warrenty acuseed useing product comercialy would fix paid fee almost equal new machine dont take chance cuisinart',
#  'love light much bought four problem stake nearly tall enough purpose eighteen inch max including light get buried plant life along driveway doesnt get enough light charge fully side doe take three minute take box hammer stake presto youve got accent light brightest light nice soft golden glow accent light also dont like put snap move',
# ...
#  'bought wife love using roti pancake cheese qasadia food never get stuck surface handle comfortable never get hot',
#  'good seal',
#  'ive using type bd coffee maker year first purchased outlet store lancaster pa wa shorter version wa unable find one back awhile ago found one last year taller version doe make good cup coffee found older version last week ordered guess got back kept old one fortunately cleaned use till new one come throwing version coffee come weak since first one ive others used hung kept dad house south jersey use visited super storm sandy came along lost along house',
#  'apple peeler functional though light weight though seems work described ad would recommend occasional use',
#  'love little timerit well built doesnt make loud ticking noise bell right volume carry pocket sometimes need time thing great product',
#  'pod work nespresso essenza machine doe work well buy',
#  'used cooker several time problem report shipment came quicker expected tried several different recipies even bbq great',
#  'put dancing flower christmas giftseveryone loved winter cold wa cheery',
#  'aerator fine work guess kind hard tell absolutely instruction came lovely card said email free ebook tip response ive emailed several time tracked website absolutely purchase one try go contact u page completed ha information found facebook left post response found one people seemed involved company facebook page messaged response id love love product company make impossible horrible customer service horrible',
#  'pressure cooker like one shown picture return disappointed',
#  'bought toaster month ago look really spiffy first thing wa pull apart drill hole annoying att beeper thats motherboard inside toaster apparently kitchenaid engineer dont make breakfast enough realize bread done toasting pop hey rod serling novel huh quiet church mouse doe good job toasting sort item bagel option make nicely toasted inside soft outside reheat also helpful option standard toasting doe fine although wonder doesnt dry bread much wa something read review hard sayso speak overall pretty impressive larnyx cut outalong warranty',
#  'star trek fan idea gift awesome bought christmas gift another star trek fan opened gift wrap found broken seller take responsibility wrap properly im finding refund policy work since july surgery amount paid plus shipping wa worth im highly disappointed gift person im almost ',
#  'cheap rusted washing',
#  'good thing colour mine lasted month heating element blew month wa ok paint underneath glass plate began peel several month seemed like really cheaply made appliance wouldnt buy anything else magic chef',
#  'used beer tasting party perfect',
#  'flimsy',
#  'wish strap wa removable wash bottle work great nice feel bottle texture',
#  'havent used embossing tool yet actual clikit cant punch complete circle piece copy paper wont punch thin piece paper supposed go cardstock wont even test scrap may keep ha emboss better got embossing tool worse come worse sell ebay',
#  'keep food warm ha two setting lowmedium warming tray hot touch think may buy two tray love theyre stylish',
#  'like wooden wa expecting bit bigger x dark brown light brown also using refuse stay closed work good though grind green pretty good gotta grind time',
#  'ok thing doe work guess leaf way much juice orange tested time device give half juice get electric citrus juicer thats much waste like juicer much better asinbudtjy new p oz citrus juicer kitchen housewares',
#  'first machine purchased wa returned setting gave talcum powder grind coffee second machine broke three month warranty cool looking blue button push turn machine flat collasped inside machine closer inspection button held place weak piece plastic broke buy another one look good failure prone better choice',
#  'im pretty happy potato masher thus far high quality really ha weight doe really nice job mashing potatoesdurable feel like utensil last year year',
#  'nice cup though dont like flat bottom espresso small cappuccino cup inexpensive ok espresso cup cappuccino cup never barely hold oz liquid like double shot espresso overfills doe standard cappuccino pull',
#  'two small complaint item first difficult see readout put normal sized plate bowl second food doe get crack around button seen comment review opted purchase anyway glad love tare automatically put container turn different unit measure able easily switch great im satisfied scale',
#  'arrived cracked little cracked like splintered chipped reconsideration agree reviewer design kind pain salad predressed ice get cloudy dressing drip also shame cant refill ice tray bowl ha filled item best keeping raw veggie plain salad leaf crisp good composed salad something like potato pasta salad paid got stainless steel bowl option instead happy itbtw amazon wa great refunding broken bowl',
#  'great cheese grater ive bought several various friend relative seem like good weight feel like quality',
#  'used product soon got cut green pepper three onion product broke used chopper several year happen',
#  'great set around campfire bought joke pull friend wine drinker worked well bought several set',
#  'actually want crispy fry need test temperature lower temperature stated machine actually quite accurate according temperature gun hold relatively steady machine way high make thing actually crisp without burning deep fryer great need find temperature setting work',
#  'whats mystery doesnt whistlenow rest feel firm look great heat water like look give go dont stray far kettle water surely dry',
#  'good buy ive seen local bed bath store purchaced wife really like',
#  'martini drinking cohort love pick arent colorful like design tell weigh plastic pick giving feeling substance',
#  'first way fit four baking potato potato express unless theyre size golf ball couldnt even fit two right bat saving time cook potato individually secondly four minute like ten thats extremely small potato room temperature freshly washed nothing helped thing wa tiny bit good wa reheating roll worth money total rip',
#  'broke us unfortunately poor quality',
#  'didnt like product impossible clean making cupcake couldnt even get stuff soaking night want punch cupcake make good luck broke wa trying push',
#  'cute picturedperfect shower',
#  'like bread maker could made good bread machine despite followed instruction every time',
#  'enjoy good toaster waffle morning unfortunately toaster seems designed dense rasin bread bagel mind waffle literally leap toaster land typically behind fridge good breakfast food maybe spring toaster wound tight maybe like hunting behind fridge breakfast anyway watch toaster like hawk bring catcher mitt else buy cheaper le frisky toaster',
#  'bought yesterdaymay st one board cracked piecesi dont know happened wa chopping onion dont think happen board fine would never tell family friend buy one never mary',
#  'ive used produced beautiful cake course wanted thank',
#  'looked nice purchased small reception washed didnt think test put use unfortunately wa cracked went use leave cup underneath collect punch wa dripping night',
#  'make much easier roll tobacco truly hubby enjoying get another one',
#  'juicer great clean job extracting juice youre juicing hard fruit vegetable ',
#  'small really classy',
#  'good afternoon product stainless steel cuisinart piece cutlery set block mini pull away received apply buy product specification received knife different seen image appear box product would greatly appreciate could help realized problem move new home remove product q began try',
#  'meant family fill water cup brew great single drink cupi put master bathroom vanity builtin good price',
#  'owned product month heating element died thing work fan called office warranty replaced wa going pay shipped repaired andor replaced dont think responsible paying product last month end spending much money shipping would replace company helpful resolving problem never purchase another europro',
#  'lived europe many year dish cover similar many year use needed replacementi highly recommend save cleaning time save finger burn pulling cover cooking',
#  'coconut knife went philippine loved',
#  'like bottle feel wa worth price would buy',
#  'open certain jar lid ridge would recommend product anyone',
#  'purchased august february st longer operates ive purchased four kettle year based upon cook illustrated recommendation ha shorter lifespan previous one give next kettle new experience',
#  'small doesnt hold much pretty would much useful wa larger',
#  'product succeeds making round ice cube obviously wont crystal clear without purified water round cube great however didnt expect rack come apart second use material split rack unusable',
#  'disappointed bought month ago previously beaterblade worked well several year breaking model ha clearly value analyzed point junk since ha already cracked need try different brand buying beaterblade sadly great concept ruined cheap production value',
#  'work great clasp getting loose already understandable considering price work better expensive infusers',
#  'cup great love transition like everyone said sad night face stay even adding really hot coffee',
#  'provided screw long enough make top pot wa hoping attach theyre probably fine thin lid description universal doesnt really apply',
#  'second hamilton beach grill love simplicity versatility dad doe weekday dinner grill ha helped go good great least eye wife picky kidseven youre hotdog lover youve kielbasa grilled boiled youll never want go back',
#  'folk remember watching grandmother made delicious food similar big heavy pansextremely heavy reciprocal pro cook evenly',
#  'item broke half first time used strong enough work properly',
#  'going back maybe owned panasonic toaster oven bottom heating element first unit burnt early however wa still warranty got repaired many year use started look shabby replaced new unit around last year noticed bread wa toasting unevenly thinking perhaps would need replace road started look market offer wa disappointed panasonic longer sold toaster oven compact size important toast breadwarm pastriesmelt open faced cheese sandwichesand crisp cooky need basic oven unit offer much sized counter space looking glad back',
#  'shot glass way small difficult use hard tell actual size stock photo amount fluid hold doe make difficulty use worth terribly displeased got good laugh absurdity trying take shot together small pointless product least didnt cost much',
#  'doe work matter much coffee used coffee wa weak sealer doe seal glad wasnt expensive bunn cafe mcu make great coffee loose pod kcups filter sealing gadget save money',
#  'hookah experience use size convention grommet expected one interchangeable isnt',
#  'mixer ha much power low speed assumed mine wa defective emailed hb send another one appears mine defective based review guess buy different brand',
#  'instruction u expert need help cant tell top bottom item needed say never buy shabby chic',
#  'bought friend germany gave thumb would recommend wash diswasher',
#  'proctor waffle maker affordable way belgian style waffle expensive restaurant quality type creates larger cake hence caloriesthere really con model right recipe real maple',
#  'pan make small donut decent pan expect donut least half size usual donut shop donut ensure donut ha hole want fill cavity halfwayno like silicon bakeware cake baked evenly stuck relatively little washed fine hand dishwasher',
#  'hard replace saved buying new expensive blender hardly get used would recommend product',
#  ...]

# %%
# Split the original training dataset into one training and one validation set
# The original labels are 1 and 2, and we need to convert them to 0 and 1,
# because in pytorch for binary classification, the labels should be 0 and 1.
len_train = int(0.8 * len(X_train_bi))
X_train_rnn, y_train_rnn = X_train_bi[:len_train], []
for i in range(len_train):
    y_train_rnn.append(y_train_bi[i] - 1) # Convert label from 1 and 2 to 0 and 1

len_valid = len(X_train_bi) - len_train
X_valid_rnn, y_valid_rnn = X_train_bi[len_train:], []
for i in range(len_valid):
    y_valid_rnn.append(y_train_bi[len_train + i] - 1)

X_test_rnn, y_test_rnn = X_test_bi, y_test_bi

# %%
# Override the Dataset class
class DatasetRNN(Dataset):
    
    def __init__(self, features, labels):
        'Initialization'
        self.features = features
        self.labels = labels
    
    def __len__(self):
        'Denotes the total number of samples'
        return len(self.features)
    
    def __getitem__(self, index):
        'Generates one sample of data'
        # Select a review (string)
        s = self.features[index]
        
        # convert the string to a list of words
        s = s.split(' ')
        
        wordVec = []
        # To reduce the computational burden, I am gonna truncate each review to
        # 20 words instead of 50 words.
        for i in range(20):
            try:
                wv = model2[s[i]]
                # convert the word vector to a tensor
                wordVec.append(wv)
            except:
                pass
        if len(wordVec) < 20:
            for _ in range(20-len(wordVec)):
                wordVec.append([0 for _ in range(300)])
        
        X = torch.Tensor(wordVec)
        y = self.labels[index]
        
        return X, y

# %%
# Hyperparameters
params = {'batch_size': 64,
          'shuffle': True,
          'num_workers': 0}
max_epochs = 50

# %%
# Generate training, validation and testing datasets
train_set = DatasetRNN(X_train_rnn, y_train_rnn)
valid_set = DatasetRNN(X_valid_rnn, y_valid_rnn)
test_set = DatasetRNN(X_test_rnn, y_test_rnn)

# Generate dataloaders for the training, validation and testing datasets
train_loader = torch.utils.data.DataLoader(train_set, **params)
valid_loader = torch.utils.data.DataLoader(valid_set, **params)
test_loader = torch.utils.data.DataLoader(test_set, **params)

# %%
# Define the network architecture
class RNN(nn.Module):
    def __init__(self, input_dim=300, hidden_dim=50, output_dim=2):
        super(RNN, self).__init__()
        # dimension of inputs
        self.input_dim = input_dim 
        # number of classes (2 for binary, 3 for ternary, ...)
        self.output_dim = output_dim
        # number of nodes in the hidden layer
        self.hidden_dim = hidden_dim
        # linear layer (input --> hidden)
        self.fc1 = nn.Linear(self.input_dim + self.hidden_dim, self.hidden_dim)
        # linear layer (hidden --> output)
        self.fc2 = nn.Linear(self.input_dim + self.hidden_dim, self.output_dim)
    
    def forward(self, wordVec):
        # for each iteration, concatenate the input word vector and the output
        # of the previous hidden layer as the 'total' input of the current
        # hidden layer
        
        # only use the output layer to calculate the output when it comes to
        # the last word (i.e. the 20th word in each review)
        
        # initialize a zero tensor of shape (batch_size * hidden dimension)
        batch_size = wordVec.shape[0]
        hidden = torch.zeros(batch_size, self.hidden_dim)
        combined = torch.cat((wordVec[:,0,], hidden), 1)
        for i in range(1, 20):
            hidden = self.fc1(combined)
            combined = torch.cat((wordVec[:,i,], hidden), 1)
        output = self.fc2(combined)
       
        return output
    
    '''def initHidden(self, batch_size):
        # initialize a zero tensor of shape (batch_size * hidden dimension)
        return torch.zeros(batch_size, self.hidden_dim)'''

# %%
# initialize the RNN
model_rnn = RNN()
print(model_rnn)
# Out:
# RNN(
#   (fc1): Linear(in_features=350, out_features=50, bias=True)
#   (fc2): Linear(in_features=350, out_features=2, bias=True)
# )

# %%
# specify cross entropy loss as loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model_rnn.parameters(), lr=0.005)

# %%
# train the network

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(max_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model_rnn.train() # prep model for training
    for data, target in train_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        '''hidden = model_rnn.initHidden(64)'''
        output = model_rnn(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model_rnn.eval() # prep model for evaluation
    for data, target in valid_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        '''hidden = model_rnn.initHidden(64)'''
        output = model_rnn(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item()*data.size(0)
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model_rnn.state_dict(), 'model_rnn.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0
# Epoch: 41 	Training Loss: 0.388998 	Validation Loss: 0.392505
# Epoch: 42 	Training Loss: 0.389088 	Validation Loss: 0.394289
# Epoch: 43 	Training Loss: 0.389380 	Validation Loss: 0.409070
# Epoch: 44 	Training Loss: 0.389149 	Validation Loss: 0.395298
# Epoch: 45 	Training Loss: 0.388671 	Validation Loss: 0.390682
# Validation loss decreased (0.391509 --> 0.390682).  Saving model ...
# Epoch: 46 	Training Loss: 0.388572 	Validation Loss: 0.403108
# Epoch: 47 	Training Loss: 0.388376 	Validation Loss: 0.393567
# Epoch: 48 	Training Loss: 0.388620 	Validation Loss: 0.705327
# Epoch: 49 	Training Loss: 0.388558 	Validation Loss: 0.394136
# Epoch: 50 	Training Loss: 0.388139 	Validation Loss: 0.396384

# %%
# Test the trained network
# The same as before
def predict(model, dataloader):
    prediction_list = []
    truth_list = []
    for i, batch in enumerate(dataloader):
        # batch[0] is X, and batch[1] is y
        outputs = model(batch[0])
        _, predicted = torch.max(outputs.data, 1)
        prediction_list.append(predicted)
        truth_list.append(batch[1])
    return prediction_list, truth_list

# %%
# Load model parameters from the trained model with the lowest validation loss
model_rnn.load_state_dict(torch.load('model_rnn.pt'))

# Use the trained model to predict the testing samples
# The output is a list of tensors and a tensor consists of the predicted labels
# of a single batch of testing samples
predictions, truths = predict(model_rnn, test_loader)
# Convert predictions and truths from list of tensors to list of lists
predictions = [list(torch.Tensor.numpy(t)) for t in predictions]
truths = [list(torch.Tensor.numpy(t)) for t in truths]
# Convert predictions and truths from list of lists to a single list
predictions = functools.reduce(lambda a, b: a + b, predictions)
truths = functools.reduce(lambda a, b: a + b, truths)
# Convert predictions from (0, 1) to (1, 2)
predictions = [p + 1 for p in predictions]

# %%
# report accuracy, precision, recall, and f1-score on the testing dataset

test_stats = precision_recall_fscore_support(truths, predictions, average='binary')
precision_test, recall_test, fscore_test = test_stats[0], test_stats[1], test_stats[2]

print('The accuracy of testing dataset: {:2.1%}'.format(accuracy_score(truths, predictions)))
print('The precision of testing dataset: {:2.1%}'.format(precision_test))
print('The recall of testing dataset: {:2.1%}'.format(recall_test))
print('The fscore of testing dataset: {:2.1%}'.format(fscore_test))
# Out:
# The accuracy of testing dataset: 83.0%
# The precision of testing dataset: 82.8%
# The recall of testing dataset: 83.3%
# The fscore of testing dataset: 83.0%

# %% [markdown]
# ## It can be shown that RNN (with accuracy of 83.0%) outperforms FNN (with accuracy of 79.9%) on the same binary classification problem.

# %% [markdown]
# ## 7. Gated Recurrent Units

# %%
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.nn.functional as F
import functools
from sklearn.metrics import accuracy_score

# %%
# Enable CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ### Binary Classification

# %%
X_train_bi
# Out:
# ['ive mug le six month loved first couple month really disappointed couple thing bad another thermos mug ha lasted year first big problem terrible odor mug developed cannot get rid matter many time wash soak baking soda etc second issue lid annoying clean hollow inside fill water youre washing split two piece put back together seems like bit hassle id able overlook lid fact pick odor easily make unusable point',
#  'ordered last year started using one stopped week second one lasted week amazon ha return policy expired contact manufacturer black decker authenticated year warranty date cut plug send along get another coffee maker using one month manufacturer way get year warranty honoredi say pot awesome want fresh cup coffee time take everywhere go pleased many year one even making cup per day lasted almost year',
#  'bought product hoping reduce frequency gazebo cleaning building wood year reconciled wiping entire interiorfurnished several table chair food prep station etc least weekly traditional screen installed virtually nothing keep pollen dirt spring wa time replace wornout screen whim googled pollenproof screening material surprise discovered pollentec despite considerable expense decided give try husband glad reviewer pointed screening material darkens interior reduces air flow view inside indeed slightly blurred live small issue especially ceiling fan keep air circulating screening material truly doe work reduce almost eliminate pollen transfer outside inside find prime pollen week need vacuum exterior screen surface shop vac outfitted dusting attachment otherwise view get really distorted clinging pollen look pretty ugly boot week truly nasty pollen relented found simply swiping dry microfiber mop clean screen nicely think fall well wash inside soap water im happy pass vacuum dry mop product solved problem pleased purchase updateone pollen season laterwe midst high oak pollen season doozey year screen continue good job minimizing pollen inside gazebo notice fine coating find way inside cleaning screen daily needed remove blanket pollen coat outside screen side receives wind therefore pollen collected pollen obscures view im hosing wiping also testimony screen ability keep pollen outside one problem discovered winter thicker screen material challenging hold place spline one screen section popped wa damaged high wind coated screen heavy snow wa easily repaired spring still happy product',
#  'great quality super love design cute highly recommended',
#  'got daughter love make soup',
#  'crafty reusable item safeguard egg kid collect hen daily container allows easy sharing among friend family',
#  'wire came apart probe within month wa disappointed brand normally good',
#  'hold heat extremely well past thanksgiving friend went town fork mashing potato thought wa gonna die saw inside nothing mark left utensil clean well white glaze white day opened',
#  'broke almost immediately started using followed direction exactly didnt last five us purchase',
#  'cute really poorly made cap flimsy stiff plastic double wall wa completely sealed allowed wine seep layer',
#  'purchased chef choice model today plan use wa sharpen kitchen knife previously worn ceramic stone diamond dust coated stone year nice pocket knife also wanted sharpen literature accompanying chef choice warns electric sharpener sharpen beyond expectation understatement comlaints follows motor loud bearing loose poorly lubed side edge guide blade grab knife edge cause sharpener stop turning diamond wheel scar deface finish blade diamond wheel leave deep gouge cannot removed finish wheel although ii assembled usa made china im taking back bass pro shop bought looking better alternative',
#  'item arrived box hear broken glass inside returned wa simple see credit account',
#  'bought soninlaw thought wa great someone hard buy get one',
#  'got anniversary beautiful nicely crafted husband say cool want buy display case listing glass thoough set fyi want get one',
#  'cannot use toaster beeping sound loud wake entire house morning whoever approved design toaster working kitchen appliance business kitchenaid absolutely nothing assist problem seem convinced need alarm wake case fall asleep waiting forever toast pop buy',
#  'zak better productmuch better know product meet safety requirement zak brand',
#  'theory great idea however found theyre spill proof would like careful get top seated tray water doesnt seep since weve purchased ive seen brickandmortar store seem little pricier',
#  'burned hand steam watch might burn careful opening doe make good food',
#  'never figured use',
#  'qt dutch oven excellent cookware price look great distributes heat well buy product line',
#  'holder make dont use pot holder work pretty good buy',
#  'im fancy cook knew needed skillet wasnt flaking nonstick food decided go handle sometimes careless handling amazing im glad went coating fine handle according instruction',
#  'tried use make chocolate horn kept breaking looked good horse needed unicorn work',
#  'aluminum rivet insight stick pan stick burn omelet easy cleaningcuisinart added buy list',
#  'way better metal one mom comfortable grip great whipping cream egg unfortunately teenage son used mix cookie dough stripped plastic gear buy one respect limitation happy',
#  'set two arrived single tried reorder thing rip get one despite description',
#  'flimsy worth money sure made cardboard fell apart wa expecting better quality',
#  'everything stick pan ive tried seasoning always using oil food still stick',
#  'seed arrived quickly problem getting germinate plant healthy quite prolific however pepper white red like typical bhut jolokia pepperthe pepper nice hot wa really hoping bright white pepper quite unfortunate spend several month growing seed find mislabeled somewhere along way',
#  'excellent itemimy small drawback wa hoping would little hefty metalother excellent',
#  'happy glass',
#  'didnt like fit finish terrible returned toaster day received',
#  'really like little big wa wanting use kitchen guess grill like jim sullivan',
#  'design wa nice would nicer strainer smaller hole tea leaf still slipping making tea hard drink',
#  'broke easy',
#  'returned nd system doe give requested ounce time consistently gave good dose coffee ground old elite wa great dont bother one pretty face',
#  'wa accompanying information brand material said fda approved',
#  'bit zip middle button closure trying keep something insulated cold dont leave wide open',
#  'replaced k machine option onepot coffee one cup use k cup regular coffee',
#  'dont lid cover',
#  'purchased replace old ceramic compost crock brokentotal piece junk',
#  'definitely big mug thats ha going definitely thermal insulated pour water tea within minute exterior hot wa supposed keep tea warm doe look nice look like work doesnt',
#  'toaster oven awesome great toast baking reheating never burned love bright light see whats going inside inside rack removable making easy clean issue one great product',
#  'say thermometer month little early say much far like lot tried thermometer took long give temperature reading felt food time cool reading fast promise',
#  'durable high quality kitchen tool easy use easy clean',
#  'make great ice cube expectedthe problem ha getting bottom half mold add hot water loosen enough pop free could easily problem related anything filling noncooperative freezer doesnt lessen effectiveness product',
#  'item made china ',
#  'great detail great seller',
#  'product arrived promptly adequately packaged high life design set individual box wa mention made box like knowing expensive stuff really made glass glencairn glass engraved bottom nifty manner stylish modern design made good quality clear glass priced reasonably well compared single malt glass amazon single malt enthusiast looking modern look good price point would like product',
#  'ring seemed little large really squish get slot doe job pressure cooker longer leak pressure replaced old original sealing ring much earlier',
#  'first issue filter received filt ha mesh pressed steel like metal hole punched much like top spice shaker let tea particle convenance started drinking whole leaf tea im missing lot tea pantry filterall together im disappointed cant get filter im sure throw im daily tea drinker wa hoping find tumbler fit spent little bought another teavana tumbler bad glass good quality filter much time time lid would leak tightened beyond easily opening',
#  'bought unit make beef jerky work well nothing fancy get job done also cheapo someone gave work well nesco main difference nesco ha temperature adjustment youre looking dependable dehydrator id recommend order extra tray',
#  'love also straw curved end great well environmentally friendlyno need plastic',
#  'neat unit dont want use stove top kettle',
#  'barely sharpens older model wa much better',
#  'love work warmer day ill probably buy think dishwasher safe usually hand wash safe',
#  'love say blueq stylist trendy environmentally conscious made recycled material',
#  'received mug disappointed look cheap paid almost twenty dollar per mug inside mug pitting appears black spot also handle sloppily connected mug silver color around base handle even mug pure copper mug supposed lovely shiny pink ha permanent discoloration inside also apparently coated lacquer reduce tarnishing probably wa description id prefer without lacquer anyway dont buy gift someone really like nice thing pay attention detail',
#  'cheaply made blade cant even handle simple frozen fruit without jamming speed setting get stuck matter button push stay stuck speed',
#  'great buy',
#  'product really good reliable easy work',
#  'solid knife good feel got freebie chef knife price wa right use often ha held well',
#  'mug box received say nican nikon pictured disappointed item different pictured',
#  'one cup arrived handle detached cup poor welding otherwise ood product',
#  'great packaging idea cover probe ala resettable screw may feature needle wa well set paint flaked didnt work course may single dud otherwise stellar part ala work medelighted amazon return process made return painless',
#  'old rubbermaid drainer tray wore year year use tried multiple modern drainers drying mat whole gamut nothing keep kitchen counter cleaner drier easy keep clean rubbermaid drainer tray happy amazon offered product great price buy rubbermaid product amazon',
#  'may well good product never got chance find opened package came wa treated tiny shard glass pouring packaging',
#  'wife would often boil egg week sunday afternoon weekend often frequently working something else instance pot boiling dry decided look alternative lot research amazon selected nordic ha worked well egg consistently hard boiled soft partially boiled also eliminate kitchen mishap',
#  'guess review pretty good purchased product back writing see star rating equal star case purchased would never done wa actually pleased functionality product worked give star since died year certainly resulted lower rating based review read amazon guess fortunate lasted long market another coffee maker would recommend purchase product',
#  'buy piece junk purchased month ago past time return started emitting disgusting putrid smell permeated house paid repairman fix microwave never guessing wa microgoround wa creating horrific toxic stench angry cant return refund must programmed fall apart day wa',
#  'mug ha proposition warning product contains chemical known state california cause cancer andor birth defect reproductive harmthe mug look great called tiki penholder',
#  'didnt know expect wa pleasantly surprised butterfly pretty simple use look lovely cupcake packaging wa well done',
#  'brita filter great job filtering water thought large capacity dispenser system wa convenient within day purchase wa leaking repaired tightening nut bolt system spout month later struggling mold building corner wash dispenser weekly warm soapy water nonabrasive brush sharp corner inside also around spout difficult clean mold build got rid purchased glass capacity pitcher brita rounded design inside le likely grow vegetation',
#  'bought replace different brand stopped working correctly using month one much better right beginning',
#  'machine user friendly direction well written easy follow recommend anyone familiar making espressosteaming milk barista wanted something house never compare commercial grade machine work well home use used machine month ha begun leak sort leak coming bottom machine leaf puddle machine first thought wa forget empty water resevoir one time left entire counter covered waterbut even dumping water use still get puddle water machine wa going call company bc ha one year warranty receipt wa thrown away need receipt recommend machine keep receipt case need utilize warranty within first year break one year still good deal bc price low',
#  'plastic top cup snap snap form happen within first dozen us use clip keep stick straight watery mix needed thick mix clean great generally think good make lot popsicle party',
#  'little k cup simply expensive buy coffee fiend fit ezcup plastic reuseable insert save allot money using insert nice filter washing cup simply pitch filter use next coffee making couple cup prefill filter next person waiting even faster',
#  'using hand held opener almost twenty year needed replace remembered old pink electric opener mom much liked using still ha pink opener wanted something sleek cool west bend fit bill sleek modern fast pleasure use opened wa larger wa expecting got four star worked officially thrown old handheld one could would give product four three quarter star highly recommend',
#  'work grate bought shred cheese preshredded cheese coated potato starch keep clumping package potato starch affect cheese melt plus trying avoid unnecessary addition food',
#  'mug held cup liquid wa great feature thought family recently discovered drinking glass supply dwindled wa time get new one house could break ordered hardy looking mason jar mug problem wa couldnt fit finger handle year old son wa one asked sure wanted mason jar drinking mug one could fit part gripping hand intended handle managed finger tip wa managed finger knuckle yay great mugsfor decoration real useunless youre leprechaun theyd fit perfectly bizarre anyone know get real mason jar mug like old boyfriend back let know sorry husband great mug',
#  'received bread maker gift inlaws wa new hadnt market long month stopped working used factory warranty mailed back cuisinart replaced new one ha started giving problem month use machine often make large dough dont use bread maker baking mixing kneading dough machine ha probably used ten time last six monthsi recommend bread maker doesnt last long look great feature nice going work worth owning motor doesnt power last',
#  'splatter guard fit well multiple size pan doe great job keeping hot grease eye arm unlike older splatter guard replaced handle completely heat resistant sturdy wellmade wash reasonably easy',
#  'small',
#  'grinder broke within week use e',
#  'sister got dad father day last weekend got try ice come beautiful shaved ice made perfectly slushy margarita even make kid sno cone hitting shave topping syrup buy store important use margarita mix thing come watery use frozen limeade mix relatively cheap think frozen consistency help make drink slushy adjust amount taste used half full real tart margarita may better luck margarita mix u try watery decided go limeade came great every time love machine jealous dad ha one strongly hinted everyone party would great gift idea hopefully ill get one christmas expensive course real cool toy oh yes monster size unit fun use became focal point party everybody standing around talking made drink dad love ease use love cause margarita anytime',
#  'somewhat challenging clean good starter spiral slicer work especially well zucchini finally decided get larger spiralizer order cut vegetable like potato beet possible tool',
#  'garbage spend little get real blender tried use maybe time multiple recipe many order ingredient change gave bought better one literally ended putting smoothie mixture food processor time doesnt really make smoothie better blender literally didnt anything pour spout difficult clean maybe wa mine wa loud wa worried wa going explode whirring noise got louder louder til stop since wasnt anything anyways',
#  'terrible save money business artland simplicity emailed dont even bother give courtesy answer',
#  'finally decided get kitchen scale counting food goldfish cracker biscuit shredded wheat wa getting kind ridiculous volume suboptimal way measuring solid scale easy use far tell reliable sometimes onofftare button take try turn device sometimes put scale away let shut also button click unexpectedly loud dont affect functionality unit im satisfied purchase',
#  'use drink lemon water everydayaaa',
#  'bought make chocolate spoon christmas gift terrible smell opened package like feel look spoon wouldnt use food use nonfood related gift already wouldnt purchase',
#  'love',
#  'worked great',
#  'purchased two slicer lasted month case adjusting wheel broke first one broke contacted oxo told ship defective slicer replacement worth effort expense inexpensive item husband convinced buy second one idea still extra wire slicer really worked well maybe got faulty product cheese slicer later willing admit lemon search decent slicer continues',
#  'robust well manufactured ability preheat tight fitting dual filter make great cup joe every time',
#  'cheery whimsical mug fact cute sitting next kuerig machineand dont many appliance knickknack bright red glaze darling',
#  'auto shutoff',
#  'good product little small doe great job',
#  'like cute package didnt include recipe card page protector hassle',
#  'started chip day hand washed trying submit warranty claim little response gone ceramic',
#  'wa looking forward coffee pot could take outside fresh hot coffee morning without going back refill unfortunately coffee pot pours coffee counter overflow generally make big mess clean since already thrown box away wasnt sure could return using old coffee pot brew pour caraf doe anyone know cure',
#  'wa giftshe wa delighted ha used yet',
#  'good reiable toaster',
#  'wa gift opened said really like needed itthanks',
#  'doe fit keirugs waste money',
#  'within hour container strawberry become mushy one started mold drainage tray take considerable amount space base container tray keep produce setting water container ventilated enough prevent condensation building fruit thus supercharging condition necessary grow mold mildew wa able put fruit container upon comparison fruit left packaging store wa proven wa fruit wa spoiling container wa holding moisture im sure fruit vegetable slightly moistplump fruit strawberry blueberry blackberry raspberry failed miserably',
#  'bought store ounce coffee thinking would ample space nope put bag inside container confused item falsely advertised',
#  'brush wa rigid enough bought another one worked better',
#  'need say micro mini disappointed size',
#  'really enjoying grapefruit juicer love product attention detail silicone ring bottom prevents slipping juicing made purchase one many others listed although expensive im extremely satisfied product made japanwhat con actually pro love grapefruit juice lot pulp like doesnt pulp strainer',
#  'tier party cake stand one admired item kitchen used wedding centre piece wedding cake truly wonder behold good price great product',
# ...
#  'love smaller sizeperfect sauce serving one',
#  'originally simply adored microwave three year longer serviceable way sad part dont even use microwave muchjust reheating occasional leftover making hot water happened let clear function microwave still work microwave functioned perfectly exception one fatal flaw design tendency microwave seems going towards one push button door pop shut push door closed sound simple right back microwave flat doe fit flush wall pushing door shut meant pushing actual microwave time door seem want latch without bit oomph really push firmly latch gradually firm push wasnt enough required forceful push graduated outright slamming repeated slammingyou see going three year unable get door stay shut perfectly designed cheerful multitasking hightech microwave going landfill le expensive buy new one repair latch next microwave going proper handle open close door push button price bit attention paid durability latch without functioning latch microwave doesnt even work breadboxwe totally unplug light buhbye',
#  'work well opener',
#  'good quality espresso machine complaint seller wrapped original flimsy product box brown paper shipped time arrived side box wa caved thought item wa certainly broken fortunately wasnt broken since bought christmas gift found pretty embarrassing give box condition simply enclosing shipping box would prevented issue',
#  'came described work great',
#  'definitely buy insanely cheap broke immediately wa trying slice honeycrisp apple blade broke inside apple punctured hand wish could write farberware cant seem find dont product website surprise',
#  'noisy take longer manual opener also exactly perpendicular extract cork bottle really difficult remove cork opener',
#  'terrific making soup stew fill turn leave let workthe handle good carrying pot luck party easy cleanup well',
#  'perfect accessory perfect camping accessory shipped promptly exactly described would definitely buy product',
#  'corning ware good product led better dont think last long cup good size round dish little small item delivered time',
#  'use time',
#  'bought smaller adjunct year old large roundbottom wok hoped might able toss food well stir fry negatory slope gradual cant hook food backwards toss lunge forward enough catch food bounce side near hand scatter place flat bottom similarly make impossible use chan decent utensil stir fry get chan speed move food around blang hit flat bottom rounded front utensil seasoned well hotashades outside burner got inside put food wa huge disappointmentdonate pile',
#  'unlike reviewer flute come broke however received one thought wa receiving two ordered special bride toasting flute would unique plain one thought wa getting doublechecking order see labeled singular term fluteit good quality something think would paid piece price could gotten engraved flute bit memorable wedding feel duped',
#  'nonstick coating isnt plain old anodized aluminum work better worse coating flake already discarded frying pan much worse guarantee least none found use stainless steel clean work well last forever',
#  'great cheap blender get pay expect much made smoothy worked great',
#  'extremely delicate champagne flute got set wedding lovely enjoyed one broke chipped thought could replace amazon date shipped item three time time arrived broken first time one wa broken second third time broken wa requested ship wa carefully packaged wa padding peanut bubble wrap air bag product box wonder arrived broken final conclusion item unshippable strongly recommend buy amazon find locally get theyre lovely dont get',
#  'bought pan shape used cake baked properly coating pan peeled pan wa removed oven',
#  'pot fit quite well asinbantg kuhn rikon cup th burner pot im using two double boiler heat milk yogurt making bmp bain marie pot tall enough fit kuhn rikon pot enough space water surround quart milk id probably want larger outer pot making quart milkthe bmp make easy heat milk temperature without burning stainless steel cool quickly put pot cool water instead waiting minute milk get cool enough add yogurt starter take minute water bath',
#  'packaging wa phenomenal reason star fact tighten press top bottom cap always cut hand tightening loosening done pressing',
#  'wa little disapointed finally realize real food chopper start magic bullet finish slap chopper magic bullet doesnt chop everything start go far work nice doesnt advertises',
#  'bought cutting board save plate husband grab whatever available chop slice death every single dish owngrrrr bought love light strong endure happy chopping going although wished little bigger serf purpose hit husband head long enough get used lol ',
#  'toaster year started toasting one side couple week ago im upset manufacturer make inferior product purpose go buy new one short time anyone recommend durable toaster please let know even exists day age',
#  'product available le store near place holland mi amazon loosing credibility quality day day may world largest store poor quality service amazoncom search give unnecessary irrelevant product waste time money amazoncom quality guaranteed low go alternative like overstockcom target store bestbuy quality latest product',
#  'received grill xmas last year absolutely love come handy midnight craving burger pop frozen patty minute burger bun warmer great like bun warm however prefer toasted rarely use feature really good gift one two people since cooking surface small think little family grows going invest larger foreman without bun warmer',
#  'great product good storage cannot used canning',
#  'thermos ounce model hold good deal coffee tea right amount whole day worth drinking although holding ounce would idealif thermos corrects fault winner im back using older smaller thermos',
#  'im happy weight size pan released cornbread first time used big plus',
#  'impressed wasnt expecting high quality purchased wa really disappointed bent first use mashing cooked strawberry spent dollar gotten one would last',
#  'save money use coffee keurig',
#  'way heavier duty thought wa going make sure adjust recipe accordingly',
#  'tricky use still leaf hole knife initial touch point remainder knife sharppppmaintained life extension wusthof happy imagine user error requires quite lot concentration precision make sure knife glide smoothly without pivoting',
#  'made look much easier arrived tried twice went back old way would invest',
#  'two non stick pan past get tired peeling wont use pot large could cook several package spaghetti noodle time danger boil happy pan would recommend anyone locking lid work great',
#  'read review tried baby itdidnt put dishwasher didnt use super hard stuff took month nice big crack like old one disappointing',
#  'decorative thing irks make star instead row want row single flavor able evenly divided flavor would preferred pod row nespresso pack come pod mean awkwardly stuck left pod different flavor',
#  'similar product year decided knife sharp enough lately wa time replace new one fantastic serious cook many knife well loved utilized sharpens ease excellence actually work better electric chef choice sharpener although also older model easy use store excuse dull knife model husband love',
#  'sharp knife hold edge long time however prepared small nick edge using knife hard material example bone',
#  'nice baking cupcake',
#  'used twice problem actually used keep fondue made warm gf surprised birthday cake ball used melt chocolate basically id say worth buy hope somebody make cake ball',
#  'work well good price',
#  'love picture bought mom set love length butter knife work well getting peanut butter mayo jar scraping bowl mixing small item granola yogurt hope help',
#  'purchased opener based review dont know talking possible open cant return past time allowed tonight wa first time needed open would open period wa wiggle room amount playing would make work heavyweight opener disappointed hamiliton beach ask question bought wa told would open disappointed reply id received time darn darn darn',
#  'seemed like nice peeler purchased gift someone else used',
#  'cup leaked go contacted maker required send entire cup back versus lid cost send cent lid god sake showed receipt',
#  'bought dessert plate extremely well packed plate beautiful love',
#  'bought product december june black non stick coating wa waffle since wa month beyond year warranty cuisinart told buy new one used waffle iron non stick spray butter cleaned according instruction expected last longer certainly buy another cuisinart waffle iron planned obsolescence think',
#  'chose product ease use versatility look great worked perfectly would recomment one looking buy slow cooker',
#  'good quality broken get fixed using high hope return paid extra day delivery didnt want pay againso someone fix le price',
#  'piece first class nice stainless work perfectly heavy shiny right way large way work wa proud use thinking order christmas gift family dont hesitate order need stainless serving utensil',
#  'number thing like espresso machine continue let know returned espresso machine im purchasing replacing one ive year sadly emotional time seriously thing machine frustrating someone ha taken simple process made complicated shouldnt take minute simply start machine order prepare espresso despite instruction telling wa necessary want wait minute machine warm waking cup coffee filter come two size unfortunately make coffee strength filter allow even larger filter size wa unsatisfactory strong cup espresso cappuccino latte strange reason another filter ha aligned perfectly within filter holder cant drop design seems pointless take time like frothing plastic piece required take time clean milk got trapped inside could simply wipe removing filter youre guaranteed get additional coffee dripping onto pan yes removable want take another step clean well little space area coffee dispensed short container demi tase cup forget wife got tired hearing complaining insisted return exchanging product basic model cost le back making coffee shot le minute little cleaning love amazon thanks making easy return processif someone fine taking minute ashot coffee go may love machine number review clearly state',
#  'read review water bottle water shooting opening thought wasnt common occurence ha happened u almost every day wa used son ha taken camp summer bothered happening actually think really cool try make time want water bottle spray water everywhere open like hasnt leaked around top easy son drink straw would recommend others',
#  'price one tray rather exorbitant purchased item bed bath beyond new york please adjust cost',
#  'ok glass misdescribed easily eight plus ounce glass six though packaging wa exactly people found received four perfect glass bad arent elusive six oz martini glass offered detail ',
#  'great product wish programmable start time',
#  'bought always got bored grinding pepper regular pepper mill food got peppery enough batteryoperated grinder really good thing solve problemthe pepper mill doe come required battery need four aaa doe pepper think pepper wa good quality',
#  'awesome knife',
#  'bought september loved using unfortunately longer work quit middle cooking lunch heard made salton maker sandwich maker thing',
#  'broke month purchase worked well expect last cheap',
#  'received product wa disappointed candy eye one shown tcp global said working correcting picture refunded money let keep incorrect eye satisfied customer',
#  'work great easy clean work great would make great addition anyones kitchengrilling tool',
#  'worthless',
#  'staty away waste moneyit blend anything worst hand blender',
#  'bought inch skillet like set try used month loved ordering set wa looking forward except stainless lid first time cooked large pot boiled rib salt pepper garlic boiled side actually damaged finish cleaned cleaned wa permanent stripe side liquid ran inside exterior bottom breeze clean red enamel sent mine back ordered black anodized set nearly pretty durable easy keep looking good',
#  'good price break easily would buy',
#  'wife bought publix wanted review pricy yes get pay hopefully dont know low rating came mine far superior others cost sharper longer metal screw part arm comfy work easily btw think product defective return simple',
#  'although worked initially kitchen aid beater blade soon cracked along one side strut replaced metal blade',
#  'whole set wusthof classic knife thought knife would good cutting hard cheese like parmesan said would wrong unlike knife one doe seem sharp use afraid going slip would recommend one',
#  'great many thing besides cooky great shaping friuts breadsjellos many item well buy',
#  'old microwave one wa almost year old wa logic wa still good condition husband wanted surprise microwave anniversary opened box microwave wa dented one side took back replaced another one looked nice pleased amount stuff book said could hour later wa dead ugh started smoke made crackling noise shortly stopped heating took back store gentleman return counter said lot return model advicestay away emerson microwave professional',
#  'orginal charger toothbrush stopped working charger work great replacement allows continue using toothbrush',
#  'love people finally starting recycle reuse much plastic work well seem pretty nice',
#  'plastic insert rounded second use coarse grinding pepper look great though wish would worked coarse grinding doe add stress plastic insert due extending passed center post',
#  'product good received item instead cup bowl missing lid',
#  'way short ',
#  'microwave tolerance low literaly burnout first try careful',
#  'product lasted year broke needed overhaul cellar wa designed professional insulated per highest standard hvac repairman told u break year need radiator compressor replaced ha good repair business going fixing exact unit unit koolspace make living fixing koolspace product buy product',
#  'absolutely loved product started unpack today found broken cap exchanged another one another store since wa closer husband job thinking wa likehood happening twice two different store sure enough open find broken cap havent even gotten use yet nothing hassle',
#  'looked store try match one nope desperation looked wa thrilled see new steak knife would identical home',
#  'battery compartment defective scale battery shift stay place even closed compartment flat surface break circuit scale doe work consistently flash turn simply doe turn first place',
#  'doe chop apple similar fruitsvegetables described',
#  'love look wrapper required much work fit standard cupcake beware cut tape theyd fit',
#  'smaller look',
#  'update third one died month dont buy po wont buy anotherupdate third one died month dont buy po',
#  'inch round grill pan replaced longtime favorite became damaged move ive never looked back grilling ridge little lower previous pan grill mark consistent cooking even lower flame cleanup breeze weight perfect really need helper grip sized panand gently arched cooltouch handle doe require potholder already cuisinart multipan lid vent pan wa great addition kitchen',
#  'ordered new product received used one jar lid visible scratch mark clearly evident used one one jar ha also white powder probably batter dough prepared jar lid also made flimsy plastic sturdy item wa packed properly came without outer box unsatisfied purchase im going return spite negative review tell used item shipped take chance received used one going order different mixer seller see going ship usedrefurbished item pay full price new product expect new product used refurbished one',
#  'would gave star however pulp go thru slot like size price good look like glass would recommend',
#  'gadget oxo good grip mini chopper absolutely doe workit small weak chop even small onion bulb',
#  'compact efficient also shipped quickly',
#  ...]

# %%
# Split the original training dataset into one training and one validation set
# The original labels are 1 and 2, and we need to convert them to 0 and 1,
# because in pytorch for binary classification, the labels should be 0 and 1.
len_train = int(0.8 * len(X_train_bi))
X_train_gru, y_train_gru = X_train_bi[:len_train], []
for i in range(len_train):
    y_train_gru.append(y_train_bi[i] - 1) # Convert label from 1 and 2 to 0 and 1

len_valid = len(X_train_bi) - len_train
X_valid_gru, y_valid_gru = X_train_bi[len_train:], []
for i in range(len_valid):
    y_valid_gru.append(y_train_bi[len_train + i] - 1)

X_test_gru, y_test_gru = X_test_bi, y_test_bi

# %%
# Override the Dataset class
class DatasetGRU(Dataset):
    
    def __init__(self, features, labels):
        'Initialization'
        self.features = features
        self.labels = labels
    
    def __len__(self):
        'Denotes the total number of samples'
        return len(self.features)
    
    def __getitem__(self, index):
        'Generates one sample of data'
        # Select a review (string)
        s = self.features[index]
        
        # convert the string to a list of words
        s = s.split(' ')
        
        wordVec = []
        # To reduce the computational burden, I am gonna truncate each review to
        # 20 words instead of 50 words.
        for i in range(20):
            try:
                wv = model2[s[i]]
                # convert the word vector to a tensor
                wordVec.append(wv)
            except:
                pass
        if len(wordVec) < 20:
            for _ in range(20-len(wordVec)):
                wordVec.append([0 for _ in range(300)])
        
        X = torch.Tensor(wordVec)
        y = self.labels[index]
        
        return X, y

# %%
# Hyperparameters
params = {'batch_size': 64,
          'shuffle': True,
          'num_workers': 0}
max_epochs = 50

# %%
# Generate training, validation and testing datasets
train_set = DatasetGRU(X_train_gru, y_train_gru)
valid_set = DatasetGRU(X_valid_gru, y_valid_gru)
test_set = DatasetGRU(X_test_gru, y_test_gru)

# Generate dataloaders for the training, validation and testing datasets
train_loader = torch.utils.data.DataLoader(train_set, **params)
valid_loader = torch.utils.data.DataLoader(valid_set, **params)
test_loader = torch.utils.data.DataLoader(test_set, **params)

# %%
# Define the network architecture
# Refer to page 188 of ed3book for the details of GRU
class GRU(nn.Module):
    def __init__(self, input_dim=300, hidden_dim=50, output_dim=2):
        super(GRU, self).__init__()
        # dimension of inputs
        self.input_dim = input_dim 
        # number of classes (2 for binary, 3 for ternary, ...)
        self.output_dim = output_dim
        # number of nodes in the hidden layer
        self.hidden_dim = hidden_dim
        # linear layer for reset gate
        self.fc1 = nn.Linear(self.input_dim + self.hidden_dim, self.hidden_dim)
        # linear layer for update gate
        self.fc2 = nn.Linear(self.input_dim + self.hidden_dim, self.hidden_dim)
        # linear layer for intermediate hidden state
        self.fc3 = nn.Linear(self.input_dim + self.hidden_dim, self.hidden_dim)
        # linear layer for output
        self.fc4 = nn.Linear(self.input_dim + self.hidden_dim, self.output_dim)
    
    def forward(self, wordVec):
        # for each iteration, concatenate the input word vector and the output
        # of the previous hidden layer as the 'total' input of the current
        # hidden layer
        
        # only use the output layer to calculate the output when it comes to
        # the last word (i.e. the 20th word in each review)
        
        # initialize a zero tensor of shape (batch_size * hidden dimension)
        batch_size = wordVec.shape[0]
        hidden = torch.zeros(batch_size, self.hidden_dim)
        combined = torch.cat((wordVec[:,0,], hidden), 1)
        sigmoid, tanh = nn.Sigmoid(), nn.Tanh()
        for i in range(1, 20):
            # reset gate
            reset = self.fc1(combined)
            reset = sigmoid(reset)
            # update gate
            update = self.fc2(combined)
            update = sigmoid(update)
            # previous hidden state passes through reset gate
            hidden2 = torch.mul(reset, hidden)
            # intermediate hidden state
            combined2 = torch.cat((wordVec[:,0,], hidden2), 1)
            hidden_inter = self.fc3(combined2)
            hidden_inter = tanh(hidden_inter)
            # hidden state
            hidden = torch.mul(1-update, hidden) + torch.mul(update, hidden_inter)
            combined = torch.cat((wordVec[:,i,], hidden), 1)
        output = self.fc4(combined)
       
        return output

# %%
# initialize the RNN
model_gru = GRU()
print(model_gru)
# Out:
# GRU(
#   (fc1): Linear(in_features=350, out_features=50, bias=True)
#   (fc2): Linear(in_features=350, out_features=50, bias=True)
#   (fc3): Linear(in_features=350, out_features=50, bias=True)
#   (fc4): Linear(in_features=350, out_features=2, bias=True)
# )

# %%
# specify cross entropy loss as loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model_gru.parameters(), lr=0.005)

# %%
# train the network

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(max_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model_gru.train() # prep model for training
    for data, target in train_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_gru(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model_gru.eval() # prep model for evaluation
    for data, target in valid_loader:
        # transfer to GPU
        #data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model_gru(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item()*data.size(0)
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model_gru.state_dict(), 'model_gru.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.587332 	Validation Loss: 0.568845
# Validation loss decreased (inf --> 0.568845).  Saving model ...
# Epoch: 2 	Training Loss: 0.563591 	Validation Loss: 0.564967
# Validation loss decreased (0.568845 --> 0.564967).  Saving model ...
# Epoch: 3 	Training Loss: 0.559337 	Validation Loss: 0.563758
# Validation loss decreased (0.564967 --> 0.563758).  Saving model ...
# Epoch: 4 	Training Loss: 0.557626 	Validation Loss: 0.560760
# Validation loss decreased (0.563758 --> 0.560760).  Saving model ...
# Epoch: 5 	Training Loss: 0.556185 	Validation Loss: 0.562119
# Epoch: 6 	Training Loss: 0.555508 	Validation Loss: 0.559465
# Validation loss decreased (0.560760 --> 0.559465).  Saving model ...
# Epoch: 7 	Training Loss: 0.554636 	Validation Loss: 0.558504
# Epoch: 39 	Training Loss: 0.462710 	Validation Loss: 0.464543
# Validation loss decreased (0.486023 --> 0.464543).  Saving model ...
# Epoch: 40 	Training Loss: 0.449005 	Validation Loss: 0.460655
# Validation loss decreased (0.464543 --> 0.460655).  Saving model ...
# Epoch: 41 	Training Loss: 0.438401 	Validation Loss: 0.445204
# Validation loss decreased (0.460655 --> 0.445204).  Saving model ...
# Epoch: 42 	Training Loss: 0.430286 	Validation Loss: 0.438284
# Validation loss decreased (0.445204 --> 0.438284).  Saving model ...
# Epoch: 43 	Training Loss: 0.423248 	Validation Loss: 0.429033
# Validation loss decreased (0.438284 --> 0.429033).  Saving model ...
# Epoch: 44 	Training Loss: 0.417238 	Validation Loss: 0.425644
# Validation loss decreased (0.429033 --> 0.425644).  Saving model ...
# Epoch: 45 	Training Loss: 0.411789 	Validation Loss: 0.424326
# Validation loss decreased (0.425644 --> 0.424326).  Saving model ...
# Epoch: 46 	Training Loss: 0.405747 	Validation Loss: 0.417891
# Validation loss decreased (0.424326 --> 0.417891).  Saving model ...
# Epoch: 47 	Training Loss: 0.401336 	Validation Loss: 0.418099
# Epoch: 48 	Training Loss: 0.397250 	Validation Loss: 0.410963
# Validation loss decreased (0.417891 --> 0.410963).  Saving model ...
# Epoch: 49 	Training Loss: 0.393872 	Validation Loss: 0.406469
# Validation loss decreased (0.410963 --> 0.406469).  Saving model ...
# Epoch: 50 	Training Loss: 0.390211 	Validation Loss: 0.405000
# Validation loss decreased (0.406469 --> 0.405000).  Saving model ...

# %%
# Test the trained network
# The same as before
def predict(model, dataloader):
    prediction_list = []
    truth_list = []
    for i, batch in enumerate(dataloader):
        # batch[0] is X, and batch[1] is y
        outputs = model(batch[0])
        _, predicted = torch.max(outputs.data, 1)
        prediction_list.append(predicted)
        truth_list.append(batch[1])
    return prediction_list, truth_list

# %%
# Load model parameters from the trained model with the lowest validation loss
model_gru.load_state_dict(torch.load('model_gru.pt'))

# Use the trained model to predict the testing samples
# The output is a list of tensors and a tensor consists of the predicted labels
# of a single batch of testing samples
predictions, truths = predict(model_gru, test_loader)
# Convert predictions and truths from list of tensors to list of lists
predictions = [list(torch.Tensor.numpy(t)) for t in predictions]
truths = [list(torch.Tensor.numpy(t)) for t in truths]
# Convert predictions and truths from list of lists to a single list
predictions = functools.reduce(lambda a, b: a + b, predictions)
truths = functools.reduce(lambda a, b: a + b, truths)
# Convert predictions from (0, 1) to (1, 2)
predictions = [p + 1 for p in predictions]

# %%
# report accuracy, precision, recall, and f1-score on the testing dataset

test_stats = precision_recall_fscore_support(truths, predictions, average='binary')
precision_test, recall_test, fscore_test = test_stats[0], test_stats[1], test_stats[2]

print('The accuracy of testing dataset: {:2.1%}'.format(accuracy_score(truths, predictions)))
print('The precision of testing dataset: {:2.1%}'.format(precision_test))
print('The recall of testing dataset: {:2.1%}'.format(recall_test))
print('The fscore of testing dataset: {:2.1%}'.format(fscore_test))
# Out:
# The accuracy of testing dataset: 81.5%
# The precision of testing dataset: 81.7%
# The recall of testing dataset: 81.2%
# The fscore of testing dataset: 81.4%
